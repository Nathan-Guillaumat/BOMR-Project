# %% [markdown]
# <div style="border:1px solid black; padding:20px 20px;text-align: justify;text-justify: inter-word">
#     <strong>Project - Motor Control
#
#
# <br/>

# %%
# !pip install --upgrade tdmclient
# Out:
# Requirement already satisfied: tdmclient in c:\users\prona\appdata\local\programs\python\python311\lib\site-packages (0.1.21)
# Requirement already satisfied: websockets in c:\users\prona\appdata\local\programs\python\python311\lib\site-packages (from tdmclient) (11.0.3)
# Requirement already satisfied: zeroconf in c:\users\prona\appdata\local\programs\python\python311\lib\site-packages (from tdmclient) (0.115.0)
# Requirement already satisfied: ifaddr>=0.1.7 in c:\users\prona\appdata\local\programs\python\python311\lib\site-packages (from zeroconf->tdmclient) (0.2.0)
# [notice] A new release of pip is available: 23.2.1 -> 23.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# !pip install tqdm scipy
# Out:
# Requirement already satisfied: tqdm in c:\users\prona\appdata\local\programs\python\python311\lib\site-packages (4.66.1)
# Requirement already satisfied: scipy in c:\users\prona\appdata\local\programs\python\python311\lib\site-packages (1.11.3)
# Requirement already satisfied: colorama in c:\users\prona\appdata\local\programs\python\python311\lib\site-packages (from tqdm) (0.4.6)
# Requirement already satisfied: numpy<1.28.0,>=1.21.6 in c:\users\prona\appdata\local\programs\python\python311\lib\site-packages (from scipy) (1.26.0)
# [notice] A new release of pip is available: 23.2.1 -> 23.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# !pip install numpy matplotlib pandas scipy tqdm
# Out:
# Requirement already satisfied: numpy in c:\users\prona\appdata\local\programs\python\python311\lib\site-packages (1.26.0)
# Requirement already satisfied: matplotlib in c:\users\prona\appdata\local\programs\python\python311\lib\site-packages (3.8.0)
# Requirement already satisfied: pandas in c:\users\prona\appdata\local\programs\python\python311\lib\site-packages (2.1.2)
# Requirement already satisfied: scipy in c:\users\prona\appdata\local\programs\python\python311\lib\site-packages (1.11.3)
# Requirement already satisfied: tqdm in c:\users\prona\appdata\local\programs\python\python311\lib\site-packages (4.66.1)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\prona\appdata\local\programs\python\python311\lib\site-packages (from matplotlib) (1.1.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\prona\appdata\local\programs\python\python311\lib\site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\prona\appdata\local\programs\python\python311\lib\site-packages (from matplotlib) (4.42.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\prona\appdata\local\programs\python\python311\lib\site-packages (from matplotlib) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in c:\users\prona\appdata\local\programs\python\python311\lib\site-packages (from matplotlib) (23.1)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\prona\appdata\local\programs\python\python311\lib\site-packages (from matplotlib) (10.0.1)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\prona\appdata\local\programs\python\python311\lib\site-packages (from matplotlib) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\prona\appdata\local\programs\python\python311\lib\site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\prona\appdata\local\programs\python\python311\lib\site-packages (from pandas) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\prona\appdata\local\programs\python\python311\lib\site-packages (from pandas) (2023.3)
# Requirement already satisfied: colorama in c:\users\prona\appdata\local\programs\python\python311\lib\site-packages (from tqdm) (0.4.6)
# Requirement already satisfied: six>=1.5 in c:\users\prona\appdata\local\programs\python\python311\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# [notice] A new release of pip is available: 23.2.1 -> 23.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %% [markdown]
# <strong>Imports :

# %%
import os
import sys
import math
from statistics import mean
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from scipy.interpolate import interp1d

# %%
import tdmclient.notebook
await tdmclient.notebook.start()

# %%
await tdmclient.notebook.stop()
# Out:
#       File "C:\Users\prona\AppData\Local\Programs\Python\Python311\Lib\site-packages\ipykernel\iostream.py", line 267, in schedule
#     self.run()
#   File "C:\Users\prona\AppData\Local\Programs\Python\Python311\Lib\threading.py", line 1401, in run
#     self._bootstrap_inner()
#   File "C:\Users\prona\AppData\Local\Programs\Python\Python311\Lib\threading.py", line 1047, in _bootstrap_inner
#     self.function(*self.args, **self.kwargs)
#   File "C:\Users\prona\AppData\Local\Temp\ipykernel_45080\4043924853.py", line 16, in _run
#     local_print("Exception in threading.excepthook:",
#   File "C:\Users\prona\AppData\Local\Programs\Python\Python311\Lib\site-packages\ipykernel\iostream.py", line 575, in flush
#     self._event_pipe.send(b"")
#     ^^^^^^^^^^^^^^^^
#   File "C:\Users\prona\AppData\Local\Programs\Python\Python311\Lib\site-packages\ipykernel\iostream.py", line 145, in _event_pipe
#     self.function(*self.args, **self.kwargs)
#   File "C:\Users\prona\AppData\Local\Temp\ipykernel_45080\4043924853.py", line 16, in _run
#     self.function(*self.args, **self.kwargs)
#   File "C:\Users\prona\AppData\Local\Temp\ipykernel_45080\4043924853.py", line 16, in _run
#     s: ST = socket_class(  # set PYTHONTRACEMALLOC=2 to get the calling frame
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\prona\AppData\Local\Programs\Python\Python311\Lib\site-packages\zmq\sugar\socket.py", line 159, in __init__
#     self.function(*self.args, **self.kwargs)
#   File "C:\Users\prona\AppData\Local\Temp\ipykernel_45080\4043924853.py", line 16, in _run
#     self._bootstrap_inner()
#   File "C:\Users\prona\AppData\Local\Programs\Python\Python311\Lib\threading.py", line 1047, in _bootstrap_inner
#     event_pipe = ctx.socket(zmq.PUSH)
#                  ^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\prona\AppData\Local\Programs\Python\Python311\Lib\site-packages\zmq\sugar\context.py", line 362, in socket
#     self.pub_thread.schedule(self._flush)
#   File "C:\Users\prona\AppData\Local\Programs\Python\Python311\Lib\site-packages\ipykernel\iostream.py", line 267, in schedule
#     self.function(*self.args, **self.kwargs)
#   File "C:\Users\prona\AppData\Local\Temp\ipykernel_45080\4043924853.py", line 16, in _run
#     super().__init__(
#   File "zmq\\backend\\cython\\socket.pyx", line 332, in zmq.backend.cython.socket.Socket.__init__
#     self.function(*self.args, **self.kwargs)
#   File "C:\Users\prona\AppData\Local\Temp\ipykernel_45080\4043924853.py", line 16, in _run
#     self._invoke_excepthook(self)
#   File "C:\Users\prona\AppData\Local\Programs\Python\Python311\Lib\threading.py", line 1359, in invoke_excepthook
#     self._event_pipe.send(b"")
#     ^^^^^^^^^^^^^^^^
#   File "C:\Users\prona\AppData\Local\Programs\Python\Python311\Lib\site-packages\ipykernel\iostream.py", line 145, in _event_pipe
#     s: ST = socket_class(  # set PYTHONTRACEMALLOC=2 to get the calling frame
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\prona\AppData\Local\Programs\Python\Python311\Lib\site-packages\zmq\sugar\socket.py", line 159, in __init__
#   File "C:\Users\prona\AppData\Local\Temp\ipykernel_45080\134166037.py", line 12, in get_data
#     super().__init__(
#   File "zmq\\backend\\cython\\socket.pyx", line 332, in zmq.backend.cython.socket.Socket.__init__
#   File "C:\Users\prona\AppData\Local\Temp\ipykernel_45080\134166037.py", line 12, in get_data
#   File "C:\Users\prona\AppData\Local\Temp\ipykernel_45080\1143550603.py", line 12, in get_data
#     local_print("Exception in threading.excepthook:",
#   File "C:\Users\prona\AppData\Local\Programs\Python\Python311\Lib\site-packages\ipykernel\iostream.py", line 575, in flush
#   File "C:\Users\prona\AppData\Local\Temp\ipykernel_45080\1143550603.py", line 12, in get_data
#     event_pipe = ctx.socket(zmq.PUSH)
#                  ^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\prona\AppData\Local\Programs\Python\Python311\Lib\site-packages\zmq\sugar\context.py", line 362, in socket
#   File "C:\Users\prona\AppData\Local\Temp\ipykernel_45080\1506783316.py", line 12, in get_data
#     self.pub_thread.schedule(self._flush)
#   File "C:\Users\prona\AppData\Local\Programs\Python\Python311\Lib\site-packages\ipykernel\iostream.py", line 267, in schedule
#     self._invoke_excepthook(self)
#   File "C:\Users\prona\AppData\Local\Programs\Python\Python311\Lib\threading.py", line 1359, in invoke_excepthook
#   File "C:\Users\prona\AppData\Local\Temp\ipykernel_45080\1506783316.py", line 12, in get_data
# zmq.error.ZMQError: Too many open files
#   File "C:\Users\prona\AppData\Local\Programs\Python\Python311\Lib\site-packages\tdmclient\clientasynccachenode.py", line 78, in __getitem__
#   File "C:\Users\prona\AppData\Local\Programs\Python\Python311\Lib\site-packages\tdmclient\clientasynccachenode.py", line 78, in __getitem__
#     s: ST = socket_class(  # set PYTHONTRACEMALLOC=2 to get the calling frame
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\prona\AppData\Local\Programs\Python\Python311\Lib\site-packages\zmq\sugar\socket.py", line 159, in __init__
#     self._event_pipe.send(b"")
#     ^^^^^^^^^^^^^^^^
#   File "C:\Users\prona\AppData\Local\Programs\Python\Python311\Lib\site-packages\ipykernel\iostream.py", line 145, in _event_pipe
#     super().__init__(
#   File "zmq\\backend\\cython\\socket.pyx", line 332, in zmq.backend.cython.socket.Socket.__init__
#   File "C:\Users\prona\AppData\Local\Programs\Python\Python311\Lib\site-packages\tdmclient\clientasynccachenode.py", line 78, in __getitem__
#     v = self.var[key]
#         ~~~~~~~~^^^^^
# KeyError: 'motor.left.speed'
# Exception in threading.excepthook:
# Exception ignored in thread started by: <bound method Thread._bootstrap of <Timer(Thread-583234, started 54988)>>
# Traceback (most recent call last):
#   File "C:\Users\prona\AppData\Local\Programs\Python\Python311\Lib\threading.py", line 1002, in _bootstrap
#   File "C:\Users\prona\AppData\Local\Programs\Python\Python311\Lib\site-packages\tdmclient\clientasynccachenode.py", line 78, in __getitem__
#   File "C:\Users\prona\AppData\Local\Programs\Python\Python311\Lib\site-packages\tdmclient\clientasynccachenode.py", line 78, in __getitem__
#     v = self.var[key]
#         ~~~~~~~~^^^^^
# KeyError: 'motor.left.speed'
# Exception in threading.excepthook:
# Exception ignored in thread started by: <bound method Thread._bootstrap of <Timer(Thread-583235, started 39980)>>
# Traceback (most recent call last):
#   File "C:\Users\prona\AppData\Local\Programs\Python\Python311\Lib\threading.py", line 1002, in _bootstrap
#     event_pipe = ctx.socket(zmq.PUSH)
#                  ^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\prona\AppData\Local\Programs\Python\Python311\Lib\site-packages\zmq\sugar\context.py", line 362, in socket
#   File "C:\Users\prona\AppData\Local\Programs\Python\Python311\Lib\site-packages\tdmclient\clientasynccachenode.py", line 78, in __getitem__
# zmq.error.ZMQError: Too many open files
#     self._bootstrap_inner()
#   File "C:\Users\prona\AppData\Local\Programs\Python\Python311\Lib\threading.py", line 1047, in _bootstrap_inner
#     v = self.var[key]
#         ~~~~~~~~^^^^^
# KeyError: 'motor.left.speed'
# Exception in threading.excepthook:
# Exception ignored in thread started by: <bound method Thread._bootstrap of <Timer(Thread-583230, started 50944)>>
# Traceback (most recent call last):
#   File "C:\Users\prona\AppData\Local\Programs\Python\Python311\Lib\threading.py", line 1002, in _bootstrap
#     s: ST = socket_class(  # set PYTHONTRACEMALLOC=2 to get the calling frame
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\prona\AppData\Local\Programs\Python\Python311\Lib\site-packages\zmq\sugar\socket.py", line 159, in __init__
#     local_print("Exception in threading.excepthook:",
#   File "C:\Users\prona\AppData\Local\Programs\Python\Python311\Lib\site-packages\ipykernel\iostream.py", line 575, in flush
# zmq.error.ZMQError: Too many open files
# Exception ignored in sys.unraisablehook: <built-in function unraisablehook>
# Traceback (most recent call last):
#   File "C:\Users\prona\AppData\Local\Programs\Python\Python311\Lib\site-packages\ipykernel\iostream.py", line 575, in flush
#     v = self.var[key]
#         ~~~~~~~~^^^^^
# KeyError: 'motor.left.speed'
# Exception in threading.excepthook:
# Exception ignored in thread started by: <bound method Thread._bootstrap of <Timer(Thread-583232, started 78940)>>
# Traceback (most recent call last):
#   File "C:\Users\prona\AppData\Local\Programs\Python\Python311\Lib\threading.py", line 1002, in _bootstrap
#     v = self.var[key]
#         ~~~~~~~~^^^^^
# KeyError: 'motor.left.speed'
# Exception in threading.excepthook:
# Exception ignored in thread started by: <bound method Thread._bootstrap of <Timer(Thread-583229, started 88820)>>
# Traceback (most recent call last):
#   File "C:\Users\prona\AppData\Local\Programs\Python\Python311\Lib\threading.py", line 1002, in _bootstrap
#     self._bootstrap_inner()
#   File "C:\Users\prona\AppData\Local\Programs\Python\Python311\Lib\threading.py", line 1047, in _bootstrap_inner
#     v = self.var[key]
#         ~~~~~~~~^^^^^
# KeyError: 'motor.left.speed'
# Exception in threading.excepthook:
# Exception ignored in thread started by: <bound method Thread._bootstrap of <Timer(Thread-583228, started 69424)>>
# Traceback (most recent call last):
#   File "C:\Users\prona\AppData\Local\Programs\Python\Python311\Lib\threading.py", line 1002, in _bootstrap
#     self.pub_thread.schedule(self._flush)
#   File "C:\Users\prona\AppData\Local\Programs\Python\Python311\Lib\site-packages\ipykernel\iostream.py", line 267, in schedule
#     self.pub_thread.schedule(self._flush)
#   File "C:\Users\prona\AppData\Local\Programs\Python\Python311\Lib\site-packages\ipykernel\iostream.py", line 267, in schedule
#     super().__init__(
#   File "zmq\\backend\\cython\\socket.pyx", line 332, in zmq.backend.cython.socket.Socket.__init__
#     self._invoke_excepthook(self)
#   File "C:\Users\prona\AppData\Local\Programs\Python\Python311\Lib\threading.py", line 1359, in invoke_excepthook
#     self._bootstrap_inner()
#   File "C:\Users\prona\AppData\Local\Programs\Python\Python311\Lib\threading.py", line 1047, in _bootstrap_inner
#     self._invoke_excepthook(self)
#   File "C:\Users\prona\AppData\Local\Programs\Python\Python311\Lib\threading.py", line 1359, in invoke_excepthook
#     self._event_pipe.send(b"")
#     ^^^^^^^^^^^^^^^^
#   File "C:\Users\prona\AppData\Local\Programs\Python\Python311\Lib\site-packages\ipykernel\iostream.py", line 145, in _event_pipe
#     self._bootstrap_inner()
#   File "C:\Users\prona\AppData\Local\Programs\Python\Python311\Lib\threading.py", line 1047, in _bootstrap_inner
#     local_print("Exception in threading.excepthook:",
#   File "C:\Users\prona\AppData\Local\Programs\Python\Python311\Lib\site-packages\ipykernel\iostream.py", line 575, in flush
#     self._bootstrap_inner()
#   File "C:\Users\prona\AppData\Local\Programs\Python\Python311\Lib\threading.py", line 1047, in _bootstrap_inner
#     self._event_pipe.send(b"")
#     ^^^^^^^^^^^^^^^^
#   File "C:\Users\prona\AppData\Local\Programs\Python\Python311\Lib\site-packages\ipykernel\iostream.py", line 145, in _event_pipe
#     event_pipe = ctx.socket(zmq.PUSH)
#                  ^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\prona\AppData\Local\Programs\Python\Python311\Lib\site-packages\zmq\sugar\context.py", line 362, in socket
#     self._bootstrap_inner()
#   File "C:\Users\prona\AppData\Local\Programs\Python\Python311\Lib\threading.py", line 1047, in _bootstrap_inner
#     s: ST = socket_class(  # set PYTHONTRACEMALLOC=2 to get the calling frame
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\prona\AppData\Local\Programs\Python\Python311\Lib\site-packages\zmq\sugar\socket.py", line 159, in __init__
#     self._invoke_excepthook(self)
#   File "C:\Users\prona\AppData\Local\Programs\Python\Python311\Lib\threading.py", line 1359, in invoke_excepthook
#     local_print("Exception in threading.excepthook:",
#   File "C:\Users\prona\AppData\Local\Programs\Python\Python311\Lib\site-packages\ipykernel\iostream.py", line 575, in flush
#     super().__init__(
#   File "zmq\\backend\\cython\\socket.pyx", line 332, in zmq.backend.cython.socket.Socket.__init__
#     event_pipe = ctx.socket(zmq.PUSH)
#                  ^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\prona\AppData\Local\Programs\Python\Python311\Lib\site-packages\zmq\sugar\context.py", line 362, in socket
#     self._invoke_excepthook(self)
#   File "C:\Users\prona\AppData\Local\Programs\Python\Python311\Lib\threading.py", line 1359, in invoke_excepthook
#     local_print("Exception in threading.excepthook:",
#   File "C:\Users\prona\AppData\Local\Programs\Python\Python311\Lib\site-packages\ipykernel\iostream.py", line 575, in flush
# zmq.error.ZMQError: Too many open files
# Exception ignored in sys.unraisablehook: <built-in function unraisablehook>
# Traceback (most recent call last):
#   File "C:\Users\prona\AppData\Local\Programs\Python\Python311\Lib\site-packages\ipykernel\iostream.py", line 575, in flush
#     s: ST = socket_class(  # set PYTHONTRACEMALLOC=2 to get the calling frame
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\prona\AppData\Local\Programs\Python\Python311\Lib\site-packages\zmq\sugar\socket.py", line 159, in __init__
#     self.pub_thread.schedule(self._flush)
#   File "C:\Users\prona\AppData\Local\Programs\Python\Python311\Lib\site-packages\ipykernel\iostream.py", line 267, in schedule
#     local_print("Exception in threading.excepthook:",
#   File "C:\Users\prona\AppData\Local\Programs\Python\Python311\Lib\site-packages\ipykernel\iostream.py", line 575, in flush
#     self.pub_thread.schedule(self._flush)
#   File "C:\Users\prona\AppData\Local\Programs\Python\Python311\Lib\site-packages\ipykernel\iostream.py", line 267, in schedule
#     self._invoke_excepthook(self)
#   File "C:\Users\prona\AppData\Local\Programs\Python\Python311\Lib\threading.py", line 1359, in invoke_excepthook
#     self.pub_thread.schedule(self._flush)
#   File "C:\Users\prona\AppData\Local\Programs\Python\Python311\Lib\site-packages\ipykernel\iostream.py", line 267, in schedule
#     self._event_pipe.send(b"")
#     ^^^^^^^^^^^^^^^^
#   File "C:\Users\prona\AppData\Local\Programs\Python\Python311\Lib\site-packages\ipykernel\iostream.py", line 145, in _event_pipe
#     self._event_pipe.send(b"")
#     ^^^^^^^^^^^^^^^^
#   File "C:\Users\prona\AppData\Local\Programs\Python\Python311\Lib\site-packages\ipykernel\iostream.py", line 145, in _event_pipe
#     self._invoke_excepthook(self)
#   File "C:\Users\prona\AppData\Local\Programs\Python\Python311\Lib\threading.py", line 1359, in invoke_excepthook
#     self.pub_thread.schedule(self._flush)
#   File "C:\Users\prona\AppData\Local\Programs\Python\Python311\Lib\site-packages\ipykernel\iostream.py", line 267, in schedule
#     self._event_pipe.send(b"")
#     ^^^^^^^^^^^^^^^^
#   File "C:\Users\prona\AppData\Local\Programs\Python\Python311\Lib\site-packages\ipykernel\iostream.py", line 145, in _event_pipe
#     self.pub_thread.schedule(self._flush)
#   File "C:\Users\prona\AppData\Local\Programs\Python\Python311\Lib\site-packages\ipykernel\iostream.py", line 267, in schedule
#     super().__init__(
#   File "zmq\\backend\\cython\\socket.pyx", line 332, in zmq.backend.cython.socket.Socket.__init__
#     event_pipe = ctx.socket(zmq.PUSH)
#                  ^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\prona\AppData\Local\Programs\Python\Python311\Lib\site-packages\zmq\sugar\context.py", line 362, in socket
#     event_pipe = ctx.socket(zmq.PUSH)
#                  ^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\prona\AppData\Local\Programs\Python\Python311\Lib\site-packages\zmq\sugar\context.py", line 362, in socket
#     event_pipe = ctx.socket(zmq.PUSH)
#                  ^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\prona\AppData\Local\Programs\Python\Python311\Lib\site-packages\zmq\sugar\context.py", line 362, in socket
# zmq.error.ZMQError: Too many open files
#     s: ST = socket_class(  # set PYTHONTRACEMALLOC=2 to get the calling frame
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\prona\AppData\Local\Programs\Python\Python311\Lib\site-packages\zmq\sugar\socket.py", line 159, in __init__
#     s: ST = socket_class(  # set PYTHONTRACEMALLOC=2 to get the calling frame
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\prona\AppData\Local\Programs\Python\Python311\Lib\site-packages\zmq\sugar\socket.py", line 159, in __init__
#     self._event_pipe.send(b"")
#     ^^^^^^^^^^^^^^^^
#   File "C:\Users\prona\AppData\Local\Programs\Python\Python311\Lib\site-packages\ipykernel\iostream.py", line 145, in _event_pipe
#     super().__init__(
#   File "zmq\\backend\\cython\\socket.pyx", line 332, in zmq.backend.cython.socket.Socket.__init__
#     event_pipe = ctx.socket(zmq.PUSH)
#                  ^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\prona\AppData\Local\Programs\Python\Python311\Lib\site-packages\zmq\sugar\context.py", line 362, in socket
#     super().__init__(
#   File "zmq\\backend\\cython\\socket.pyx", line 332, in zmq.backend.cython.socket.Socket.__init__
#     s: ST = socket_class(  # set PYTHONTRACEMALLOC=2 to get the calling frame
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\prona\AppData\Local\Programs\Python\Python311\Lib\site-packages\zmq\sugar\socket.py", line 159, in __init__
#     local_print("Exception in threading.excepthook:",
#   File "C:\Users\prona\AppData\Local\Programs\Python\Python311\Lib\site-packages\ipykernel\iostream.py", line 575, in flush
#     self._event_pipe.send(b"")
#     ^^^^^^^^^^^^^^^^
#   File "C:\Users\prona\AppData\Local\Programs\Python\Python311\Lib\site-packages\ipykernel\iostream.py", line 145, in _event_pipe
#     local_print("Exception in threading.excepthook:",
#   File "C:\Users\prona\AppData\Local\Programs\Python\Python311\Lib\site-packages\ipykernel\iostream.py", line 575, in flush
#     event_pipe = ctx.socket(zmq.PUSH)
#                  ^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\prona\AppData\Local\Programs\Python\Python311\Lib\site-packages\zmq\sugar\context.py", line 362, in socket
#     super().__init__(
#   File "zmq\\backend\\cython\\socket.pyx", line 332, in zmq.backend.cython.socket.Socket.__init__
# zmq.error.ZMQError: Too many open files
# Exception ignored in sys.unraisablehook: <built-in function unraisablehook>
# Traceback (most recent call last):
#   File "C:\Users\prona\AppData\Local\Programs\Python\Python311\Lib\site-packages\ipykernel\iostream.py", line 575, in flush
#     s: ST = socket_class(  # set PYTHONTRACEMALLOC=2 to get the calling frame
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\prona\AppData\Local\Programs\Python\Python311\Lib\site-packages\zmq\sugar\socket.py", line 159, in __init__
#     self.pub_thread.schedule(self._flush)
#   File "C:\Users\prona\AppData\Local\Programs\Python\Python311\Lib\site-packages\ipykernel\iostream.py", line 267, in schedule
#     self._event_pipe.send(b"")
#     ^^^^^^^^^^^^^^^^
#   File "C:\Users\prona\AppData\Local\Programs\Python\Python311\Lib\site-packages\ipykernel\iostream.py", line 145, in _event_pipe
#     s: ST = socket_class(  # set PYTHONTRACEMALLOC=2 to get the calling frame
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\prona\AppData\Local\Programs\Python\Python311\Lib\site-packages\zmq\sugar\socket.py", line 159, in __init__
# zmq.error.ZMQError: Too many open files
# Exception ignored in sys.unraisablehook: <built-in function unraisablehook>
# Traceback (most recent call last):
#   File "C:\Users\prona\AppData\Local\Programs\Python\Python311\Lib\site-packages\ipykernel\iostream.py", line 575, in flush
#     super().__init__(
#   File "zmq\\backend\\cython\\socket.pyx", line 332, in zmq.backend.cython.socket.Socket.__init__
#     super().__init__(
#   File "zmq\\backend\\cython\\socket.pyx", line 332, in zmq.backend.cython.socket.Socket.__init__
#     event_pipe = ctx.socket(zmq.PUSH)
#                  ^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\prona\AppData\Local\Programs\Python\Python311\Lib\site-packages\zmq\sugar\context.py", line 362, in socket
#     self.pub_thread.schedule(self._flush)
#   File "C:\Users\prona\AppData\Local\Programs\Python\Python311\Lib\site-packages\ipykernel\iostream.py", line 267, in schedule
#     self.pub_thread.schedule(self._flush)
#   File "C:\Users\prona\AppData\Local\Programs\Python\Python311\Lib\site-packages\ipykernel\iostream.py", line 267, in schedule
# zmq.error.ZMQError: Too many open files
# Exception ignored in sys.unraisablehook: <built-in function unraisablehook>
# Traceback (most recent call last):
#   File "C:\Users\prona\AppData\Local\Programs\Python\Python311\Lib\site-packages\ipykernel\iostream.py", line 575, in flush
#     self.pub_thread.schedule(self._flush)
#   File "C:\Users\prona\AppData\Local\Programs\Python\Python311\Lib\site-packages\ipykernel\iostream.py", line 267, in schedule
#     self._event_pipe.send(b"")
#     ^^^^^^^^^^^^^^^^
#   File "C:\Users\prona\AppData\Local\Programs\Python\Python311\Lib\site-packages\ipykernel\iostream.py", line 145, in _event_pipe
#     s: ST = socket_class(  # set PYTHONTRACEMALLOC=2 to get the calling frame
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\prona\AppData\Local\Programs\Python\Python311\Lib\site-packages\zmq\sugar\socket.py", line 159, in __init__
# zmq.error.ZMQError: Too many open files
# Exception ignored in sys.unraisablehook: <built-in function unraisablehook>
# Traceback (most recent call last):
#   File "C:\Users\prona\AppData\Local\Programs\Python\Python311\Lib\site-packages\ipykernel\iostream.py", line 575, in flush
#     self._event_pipe.send(b"")
#     ^^^^^^^^^^^^^^^^
#   File "C:\Users\prona\AppData\Local\Programs\Python\Python311\Lib\site-packages\ipykernel\iostream.py", line 145, in _event_pipe
# zmq.error.ZMQError: Too many open files
#     event_pipe = ctx.socket(zmq.PUSH)
#                  ^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\prona\AppData\Local\Programs\Python\Python311\Lib\site-packages\zmq\sugar\context.py", line 362, in socket
#     self._event_pipe.send(b"")
#     ^^^^^^^^^^^^^^^^
#   File "C:\Users\prona\AppData\Local\Programs\Python\Python311\Lib\site-packages\ipykernel\iostream.py", line 145, in _event_pipe
#     self.pub_thread.schedule(self._flush)
#   File "C:\Users\prona\AppData\Local\Programs\Python\Python311\Lib\site-packages\ipykernel\iostream.py", line 267, in schedule
#     super().__init__(
#   File "zmq\\backend\\cython\\socket.pyx", line 332, in zmq.backend.cython.socket.Socket.__init__
#     event_pipe = ctx.socket(zmq.PUSH)
#                  ^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\prona\AppData\Local\Programs\Python\Python311\Lib\site-packages\zmq\sugar\context.py", line 362, in socket
# zmq.error.ZMQError: Too many open files
# Exception ignored in sys.unraisablehook: <built-in function unraisablehook>
# Traceback (most recent call last):
#   File "C:\Users\prona\AppData\Local\Programs\Python\Python311\Lib\site-packages\ipykernel\iostream.py", line 575, in flush
#     event_pipe = ctx.socket(zmq.PUSH)
#                  ^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\prona\AppData\Local\Programs\Python\Python311\Lib\site-packages\zmq\sugar\context.py", line 362, in socket
#     s: ST = socket_class(  # set PYTHONTRACEMALLOC=2 to get the calling frame
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\prona\AppData\Local\Programs\Python\Python311\Lib\site-packages\zmq\sugar\socket.py", line 159, in __init__
#     s: ST = socket_class(  # set PYTHONTRACEMALLOC=2 to get the calling frame
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\prona\AppData\Local\Programs\Python\Python311\Lib\site-packages\zmq\sugar\socket.py", line 159, in __init__
#     self._event_pipe.send(b"")
#     ^^^^^^^^^^^^^^^^
#   File "C:\Users\prona\AppData\Local\Programs\Python\Python311\Lib\site-packages\ipykernel\iostream.py", line 145, in _event_pipe
#     self.pub_thread.schedule(self._flush)
#   File "C:\Users\prona\AppData\Local\Programs\Python\Python311\Lib\site-packages\ipykernel\iostream.py", line 267, in schedule
#     self._event_pipe.send(b"")
#     ^^^^^^^^^^^^^^^^
#   File "C:\Users\prona\AppData\Local\Programs\Python\Python311\Lib\site-packages\ipykernel\iostream.py", line 145, in _event_pipe
#     event_pipe = ctx.socket(zmq.PUSH)
#                  ^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\prona\AppData\Local\Programs\Python\Python311\Lib\site-packages\zmq\sugar\context.py", line 362, in socket
#     s: ST = socket_class(  # set PYTHONTRACEMALLOC=2 to get the calling frame
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\prona\AppData\Local\Programs\Python\Python311\Lib\site-packages\zmq\sugar\socket.py", line 159, in __init__
#     super().__init__(
#   File "zmq\\backend\\cython\\socket.pyx", line 332, in zmq.backend.cython.socket.Socket.__init__
#     s: ST = socket_class(  # set PYTHONTRACEMALLOC=2 to get the calling frame
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\prona\AppData\Local\Programs\Python\Python311\Lib\site-packages\zmq\sugar\socket.py", line 159, in __init__
#     self.pub_thread.schedule(self._flush)
#   File "C:\Users\prona\AppData\Local\Programs\Python\Python311\Lib\site-packages\ipykernel\iostream.py", line 267, in schedule
#     super().__init__(
#   File "zmq\\backend\\cython\\socket.pyx", line 332, in zmq.backend.cython.socket.Socket.__init__
#     super().__init__(
#   File "zmq\\backend\\cython\\socket.pyx", line 332, in zmq.backend.cython.socket.Socket.__init__
# zmq.error.ZMQError: Too many open files
# Exception ignored in sys.unraisablehook: <built-in function unraisablehook>
# Traceback (most recent call last):
#   File "C:\Users\prona\AppData\Local\Programs\Python\Python311\Lib\site-packages\ipykernel\iostream.py", line 575, in flush
#     self._event_pipe.send(b"")
#     ^^^^^^^^^^^^^^^^
#   File "C:\Users\prona\AppData\Local\Programs\Python\Python311\Lib\site-packages\ipykernel\iostream.py", line 145, in _event_pipe
#     super().__init__(
#   File "zmq\\backend\\cython\\socket.pyx", line 332, in zmq.backend.cython.socket.Socket.__init__
#     event_pipe = ctx.socket(zmq.PUSH)
#                  ^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\prona\AppData\Local\Programs\Python\Python311\Lib\site-packages\zmq\sugar\context.py", line 362, in socket
#     self.pub_thread.schedule(self._flush)
#   File "C:\Users\prona\AppData\Local\Programs\Python\Python311\Lib\site-packages\ipykernel\iostream.py", line 267, in schedule
# zmq.error.ZMQError: Too many open files
#     event_pipe = ctx.socket(zmq.PUSH)
#                  ^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\prona\AppData\Local\Programs\Python\Python311\Lib\site-packages\zmq\sugar\context.py", line 362, in socket
# zmq.error.ZMQError: Too many open files
# zmq.error.ZMQError: Too many open files
#     s: ST = socket_class(  # set PYTHONTRACEMALLOC=2 to get the calling frame
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\prona\AppData\Local\Programs\Python\Python311\Lib\site-packages\zmq\sugar\socket.py", line 159, in __init__
#     self._event_pipe.send(b"")
#     ^^^^^^^^^^^^^^^^
#   File "C:\Users\prona\AppData\Local\Programs\Python\Python311\Lib\site-packages\ipykernel\iostream.py", line 145, in _event_pipe
#     event_pipe = ctx.socket(zmq.PUSH)
#                  ^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\prona\AppData\Local\Programs\Python\Python311\Lib\site-packages\zmq\sugar\context.py", line 362, in socket
#     super().__init__(
#   File "zmq\\backend\\cython\\socket.pyx", line 332, in zmq.backend.cython.socket.Socket.__init__
# zmq.error.ZMQError: Too many open files
# Exception ignored in sys.unraisablehook: <built-in function unraisablehook>
# Traceback (most recent call last):
#   File "C:\Users\prona\AppData\Local\Programs\Python\Python311\Lib\site-packages\ipykernel\iostream.py", line 575, in flush
#     s: ST = socket_class(  # set PYTHONTRACEMALLOC=2 to get the calling frame
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\prona\AppData\Local\Programs\Python\Python311\Lib\site-packages\zmq\sugar\socket.py", line 159, in __init__
#     s: ST = socket_class(  # set PYTHONTRACEMALLOC=2 to get the calling frame
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\prona\AppData\Local\Programs\Python\Python311\Lib\site-packages\zmq\sugar\socket.py", line 159, in __init__
#     self.pub_thread.schedule(self._flush)
#   File "C:\Users\prona\AppData\Local\Programs\Python\Python311\Lib\site-packages\ipykernel\iostream.py", line 267, in schedule
#     super().__init__(
#   File "zmq\\backend\\cython\\socket.pyx", line 332, in zmq.backend.cython.socket.Socket.__init__
#     super().__init__(
#   File "zmq\\backend\\cython\\socket.pyx", line 332, in zmq.backend.cython.socket.Socket.__init__
# zmq.error.ZMQError: Too many open files
# zmq.error.ZMQError: Too many open files
#     self._event_pipe.send(b"")
#     ^^^^^^^^^^^^^^^^
#   File "C:\Users\prona\AppData\Local\Programs\Python\Python311\Lib\site-packages\ipykernel\iostream.py", line 145, in _event_pipe
#     event_pipe = ctx.socket(zmq.PUSH)
#                  ^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\prona\AppData\Local\Programs\Python\Python311\Lib\site-packages\zmq\sugar\context.py", line 362, in socket
# zmq.error.ZMQError: Too many open files
#     s: ST = socket_class(  # set PYTHONTRACEMALLOC=2 to get the calling frame
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\prona\AppData\Local\Programs\Python\Python311\Lib\site-packages\zmq\sugar\socket.py", line 159, in __init__
#     super().__init__(
#   File "zmq\\backend\\cython\\socket.pyx", line 332, in zmq.backend.cython.socket.Socket.__init__
# zmq.error.ZMQError: Too many open files
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[442], line 1
# ----> 1 await tdmclient.notebook.stop()
#
# NameError: name 'tdmclient' is not defined
# Exception in thread Exception in threading.excepthook:
# Exception ignored in thread started by: <bound method Thread._bootstrap of <Timer(Thread-583238, started 14876)>>
# Traceback (most recent call last):
#   File "C:\Users\prona\AppData\Local\Programs\Python\Python311\Lib\threading.py", line 1002, in _bootstrap
# Exception in thread Thread-583239:
# Traceback (most recent call last):
#   File "C:\Users\prona\AppData\Local\Programs\Python\Python311\Lib\threading.py", line 1045, in _bootstrap_inner
# Exception in thread Thread-583237:
# Traceback (most recent call last):
#   File "C:\Users\prona\AppData\Local\Programs\Python\Python311\Lib\threading.py", line 1045, in _bootstrap_inner
# Exception in thread Thread-583236:
# Traceback (most recent call last):
#   File "C:\Users\prona\AppData\Local\Programs\Python\Python311\Lib\threading.py", line 1045, in _bootstrap_inner
#     self.run()
#   File "C:\Users\prona\AppData\Local\Programs\Python\Python311\Lib\threading.py", line 1401, in run
#     self.run()
#   File "C:\Users\prona\AppData\Local\Programs\Python\Python311\Lib\threading.py", line 1401, in run
#     self.run()
#   File "C:\Users\prona\AppData\Local\Programs\Python\Python311\Lib\threading.py", line 1401, in run
#     self.function(*self.args, **self.kwargs)
#   File "C:\Users\prona\AppData\Local\Temp\ipykernel_45080\4043924853.py", line 16, in _run
#     self._bootstrap_inner()
#   File "C:\Users\prona\AppData\Local\Programs\Python\Python311\Lib\threading.py", line 1047, in _bootstrap_inner
#     self._invoke_excepthook(self)
#   File "C:\Users\prona\AppData\Local\Programs\Python\Python311\Lib\threading.py", line 1359, in invoke_excepthook
#     self.function(*self.args, **self.kwargs)
#   File "C:\Users\prona\AppData\Local\Temp\ipykernel_45080\4043924853.py", line 16, in _run
#     self.function(*self.args, **self.kwargs)
#   File "C:\Users\prona\AppData\Local\Temp\ipykernel_45080\4043924853.py", line 16, in _run
#     local_print("Exception in threading.excepthook:",
#   File "C:\Users\prona\AppData\Local\Programs\Python\Python311\Lib\site-packages\ipykernel\iostream.py", line 575, in flush
#   File "C:\Users\prona\AppData\Local\Temp\ipykernel_45080\1143550603.py", line 12, in get_data
#   File "C:\Users\prona\AppData\Local\Temp\ipykernel_45080\1506783316.py", line 12, in get_data
#     self.pub_thread.schedule(self._flush)
#   File "C:\Users\prona\AppData\Local\Programs\Python\Python311\Lib\site-packages\ipykernel\iostream.py", line 267, in schedule
#     self._event_pipe.send(b"")
#     ^^^^^^^^^^^^^^^^
#   File "C:\Users\prona\AppData\Local\Programs\Python\Python311\Lib\site-packages\ipykernel\iostream.py", line 145, in _event_pipe
#   File "C:\Users\prona\AppData\Local\Temp\ipykernel_45080\134166037.py", line 12, in get_data
#     event_pipe = ctx.socket(zmq.PUSH)
#                  ^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\prona\AppData\Local\Programs\Python\Python311\Lib\site-packages\zmq\sugar\context.py", line 362, in socket
#   File "C:\Users\prona\AppData\Local\Programs\Python\Python311\Lib\site-packages\tdmclient\clientasynccachenode.py", line 78, in __getitem__
#   File "C:\Users\prona\AppData\Local\Programs\Python\Python311\Lib\site-packages\tdmclient\clientasynccachenode.py", line 78, in __getitem__
#     s: ST = socket_class(  # set PYTHONTRACEMALLOC=2 to get the calling frame
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\prona\AppData\Local\Programs\Python\Python311\Lib\site-packages\zmq\sugar\socket.py", line 159, in __init__
#     v = self.var[key]
#         ~~~~~~~~^^^^^
# KeyError: 'motor.left.speed'
# Exception in threading.excepthook:
# Exception ignored in thread started by: <bound method Thread._bootstrap of <Timer(Thread-583237, started 53388)>>
# Traceback (most recent call last):
#   File "C:\Users\prona\AppData\Local\Programs\Python\Python311\Lib\threading.py", line 1002, in _bootstrap
#     super().__init__(
#   File "zmq\\backend\\cython\\socket.pyx", line 332, in zmq.backend.cython.socket.Socket.__init__
#     v = self.var[key]
#         ~~~~~~~~^^^^^
# KeyError: 'motor.left.speed'
# Exception in threading.excepthook:
# Exception ignored in thread started by: <bound method Thread._bootstrap of <Timer(Thread-583239, started 76076)>>
# Traceback (most recent call last):
#   File "C:\Users\prona\AppData\Local\Programs\Python\Python311\Lib\threading.py", line 1002, in _bootstrap
#   File "C:\Users\prona\AppData\Local\Programs\Python\Python311\Lib\site-packages\tdmclient\clientasynccachenode.py", line 78, in __getitem__
#     self._bootstrap_inner()
#   File "C:\Users\prona\AppData\Local\Programs\Python\Python311\Lib\threading.py", line 1047, in _bootstrap_inner
#     v = self.var[key]
#         ~~~~~~~~^^^^^
# KeyError: 'motor.left.speed'
# Exception in threading.excepthook:
# Exception ignored in thread started by: <bound method Thread._bootstrap of <Timer(Thread-583236, started 82256)>>
# Traceback (most recent call last):
#   File "C:\Users\prona\AppData\Local\Programs\Python\Python311\Lib\threading.py", line 1002, in _bootstrap
#     self._bootstrap_inner()
#   File "C:\Users\prona\AppData\Local\Programs\Python\Python311\Lib\threading.py", line 1047, in _bootstrap_inner
#     self._invoke_excepthook(self)
#   File "C:\Users\prona\AppData\Local\Programs\Python\Python311\Lib\threading.py", line 1359, in invoke_excepthook
# zmq.error.ZMQError: Too many open files
# Exception ignored in sys.unraisablehook: <built-in function unraisablehook>
# Traceback (most recent call last):
#   File "C:\Users\prona\AppData\Local\Programs\Python\Python311\Lib\site-packages\ipykernel\iostream.py", line 575, in flush
#     self._invoke_excepthook(self)
#   File "C:\Users\prona\AppData\Local\Programs\Python\Python311\Lib\threading.py", line 1359, in invoke_excepthook
#     self.pub_thread.schedule(self._flush)
#   File "C:\Users\prona\AppData\Local\Programs\Python\Python311\Lib\site-packages\ipykernel\iostream.py", line 267, in schedule
#     self._event_pipe.send(b"")
#     ^^^^^^^^^^^^^^^^
#   File "C:\Users\prona\AppData\Local\Programs\Python\Python311\Lib\site-packages\ipykernel\iostream.py", line 145, in _event_pipe
#     self._bootstrap_inner()
#   File "C:\Users\prona\AppData\Local\Programs\Python\Python311\Lib\threading.py", line 1047, in _bootstrap_inner
#     local_print("Exception in threading.excepthook:",
#   File "C:\Users\prona\AppData\Local\Programs\Python\Python311\Lib\site-packages\ipykernel\iostream.py", line 575, in flush
#     local_print("Exception in threading.excepthook:",
#   File "C:\Users\prona\AppData\Local\Programs\Python\Python311\Lib\site-packages\ipykernel\iostream.py", line 575, in flush
#     self._invoke_excepthook(self)
#   File "C:\Users\prona\AppData\Local\Programs\Python\Python311\Lib\threading.py", line 1359, in invoke_excepthook
#     event_pipe = ctx.socket(zmq.PUSH)
#                  ^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\prona\AppData\Local\Programs\Python\Python311\Lib\site-packages\zmq\sugar\context.py", line 362, in socket
#     self.pub_thread.schedule(self._flush)
#   File "C:\Users\prona\AppData\Local\Programs\Python\Python311\Lib\site-packages\ipykernel\iostream.py", line 267, in schedule
#     s: ST = socket_class(  # set PYTHONTRACEMALLOC=2 to get the calling frame
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\prona\AppData\Local\Programs\Python\Python311\Lib\site-packages\zmq\sugar\socket.py", line 159, in __init__
#     self.pub_thread.schedule(self._flush)
#   File "C:\Users\prona\AppData\Local\Programs\Python\Python311\Lib\site-packages\ipykernel\iostream.py", line 267, in schedule
#     local_print("Exception in threading.excepthook:",
#   File "C:\Users\prona\AppData\Local\Programs\Python\Python311\Lib\site-packages\ipykernel\iostream.py", line 575, in flush
#     super().__init__(
#   File "zmq\\backend\\cython\\socket.pyx", line 332, in zmq.backend.cython.socket.Socket.__init__
#     self._event_pipe.send(b"")
#     ^^^^^^^^^^^^^^^^
#   File "C:\Users\prona\AppData\Local\Programs\Python\Python311\Lib\site-packages\ipykernel\iostream.py", line 145, in _event_pipe
#     event_pipe = ctx.socket(zmq.PUSH)
#                  ^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\prona\AppData\Local\Programs\Python\Python311\Lib\site-packages\zmq\sugar\context.py", line 362, in socket
# Exception in thread Thread-583246:
# Traceback (most recent call last):
#   File "C:\Users\prona\AppData\Local\Programs\Python\Python311\Lib\threading.py", line 1045, in _bootstrap_inner
# Exception in thread Thread-583248:
# Traceback (most recent call last):
#   File "C:\Users\prona\AppData\Local\Programs\Python\Python311\Lib\threading.py", line 1045, in _bootstrap_inner
# Exception in thread Thread-583244:
# Traceback (most recent call last):
#   File "C:\Users\prona\AppData\Local\Programs\Python\Python311\Lib\threading.py", line 1045, in _bootstrap_inner
# Exception in thread Thread-583243:
# Traceback (most recent call last):
#   File "C:\Users\prona\AppData\Local\Programs\Python\Python311\Lib\threading.py", line 1045, in _bootstrap_inner
# Exception in thread Thread-583247:
# Traceback (most recent call last):
#   File "C:\Users\prona\AppData\Local\Programs\Python\Python311\Lib\threading.py", line 1045, in _bootstrap_inner
# Exception in thread Thread-583241:
# Traceback (most recent call last):
#   File "C:\Users\prona\AppData\Local\Programs\Python\Python311\Lib\threading.py", line 1045, in _bootstrap_inner
#     self.pub_thread.schedule(self._flush)
#   File "C:\Users\prona\AppData\Local\Programs\Python\Python311\Lib\site-packages\ipykernel\iostream.py", line 267, in schedule
#     self.run()
#   File "C:\Users\prona\AppData\Local\Programs\Python\Python311\Lib\threading.py", line 1401, in run
#     s: ST = socket_class(  # set PYTHONTRACEMALLOC=2 to get the calling frame
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\prona\AppData\Local\Programs\Python\Python311\Lib\site-packages\zmq\sugar\socket.py", line 159, in __init__
# Exception in thread Thread-583242:
# Traceback (most recent call last):
#   File "C:\Users\prona\AppData\Local\Programs\Python\Python311\Lib\threading.py", line 1045, in _bootstrap_inner
#     self._event_pipe.send(b"")
#     ^^^^^^^^^^^^^^^^
#   File "C:\Users\prona\AppData\Local\Programs\Python\Python311\Lib\site-packages\ipykernel\iostream.py", line 145, in _event_pipe
# zmq.error.ZMQError: Too many open files
#     self._event_pipe.send(b"")
#     ^^^^^^^^^^^^^^^^
#   File "C:\Users\prona\AppData\Local\Programs\Python\Python311\Lib\site-packages\ipykernel\iostream.py", line 145, in _event_pipe
#     super().__init__(
#   File "zmq\\backend\\cython\\socket.pyx", line 332, in zmq.backend.cython.socket.Socket.__init__
# Exception in thread Thread-583245:
# Traceback (most recent call last):
#   File "C:\Users\prona\AppData\Local\Programs\Python\Python311\Lib\threading.py", line 1045, in _bootstrap_inner
#     self.run()
#   File "C:\Users\prona\AppData\Local\Programs\Python\Python311\Lib\threading.py", line 1401, in run
#     self.run()
#   File "C:\Users\prona\AppData\Local\Programs\Python\Python311\Lib\threading.py", line 1401, in run
#     self.function(*self.args, **self.kwargs)
#   File "C:\Users\prona\AppData\Local\Temp\ipykernel_45080\4043924853.py", line 16, in _run
#     self.run()
#   File "C:\Users\prona\AppData\Local\Programs\Python\Python311\Lib\threading.py", line 1401, in run
#     event_pipe = ctx.socket(zmq.PUSH)
#                  ^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\prona\AppData\Local\Programs\Python\Python311\Lib\site-packages\zmq\sugar\context.py", line 362, in socket
#     event_pipe = ctx.socket(zmq.PUSH)
#                  ^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\prona\AppData\Local\Programs\Python\Python311\Lib\site-packages\zmq\sugar\context.py", line 362, in socket
#     self.run()
#   File "C:\Users\prona\AppData\Local\Programs\Python\Python311\Lib\threading.py", line 1401, in run
#     self.run()
#   File "C:\Users\prona\AppData\Local\Programs\Python\Python311\Lib\threading.py", line 1401, in run
#     self.run()
#   File "C:\Users\prona\AppData\Local\Programs\Python\Python311\Lib\threading.py", line 1401, in run
#     s: ST = socket_class(  # set PYTHONTRACEMALLOC=2 to get the calling frame
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\prona\AppData\Local\Programs\Python\Python311\Lib\site-packages\zmq\sugar\socket.py", line 159, in __init__
#     self.run()
#   File "C:\Users\prona\AppData\Local\Programs\Python\Python311\Lib\threading.py", line 1401, in run
#     self.function(*self.args, **self.kwargs)
#   File "C:\Users\prona\AppData\Local\Temp\ipykernel_45080\4043924853.py", line 16, in _run
#     self.function(*self.args, **self.kwargs)
#   File "C:\Users\prona\AppData\Local\Temp\ipykernel_45080\4043924853.py", line 16, in _run
#     s: ST = socket_class(  # set PYTHONTRACEMALLOC=2 to get the calling frame
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\prona\AppData\Local\Programs\Python\Python311\Lib\site-packages\zmq\sugar\socket.py", line 159, in __init__
#     super().__init__(
#   File "zmq\\backend\\cython\\socket.pyx", line 332, in zmq.backend.cython.socket.Socket.__init__
# zmq.error.ZMQError: Too many open files
# Exception ignored in sys.unraisablehook: <built-in function unraisablehook>
# Traceback (most recent call last):
#   File "C:\Users\prona\AppData\Local\Programs\Python\Python311\Lib\site-packages\ipykernel\iostream.py", line 575, in flush
#   File "C:\Users\prona\AppData\Local\Temp\ipykernel_45080\1143550603.py", line 12, in get_data
#     self.function(*self.args, **self.kwargs)
#   File "C:\Users\prona\AppData\Local\Temp\ipykernel_45080\4043924853.py", line 16, in _run
#     self.function(*self.args, **self.kwargs)
#   File "C:\Users\prona\AppData\Local\Temp\ipykernel_45080\4043924853.py", line 16, in _run
#     self.pub_thread.schedule(self._flush)
#   File "C:\Users\prona\AppData\Local\Programs\Python\Python311\Lib\site-packages\ipykernel\iostream.py", line 267, in schedule
#     self.function(*self.args, **self.kwargs)
#   File "C:\Users\prona\AppData\Local\Temp\ipykernel_45080\4043924853.py", line 16, in _run
#     self.function(*self.args, **self.kwargs)
#   File "C:\Users\prona\AppData\Local\Temp\ipykernel_45080\4043924853.py", line 16, in _run
#     super().__init__(
#   File "zmq\\backend\\cython\\socket.pyx", line 332, in zmq.backend.cython.socket.Socket.__init__
#   File "C:\Users\prona\AppData\Local\Temp\ipykernel_45080\1506783316.py", line 12, in get_data
#     self.function(*self.args, **self.kwargs)
#   File "C:\Users\prona\AppData\Local\Temp\ipykernel_45080\4043924853.py", line 16, in _run
# zmq.error.ZMQError: Too many open files
# Exception ignored in sys.unraisablehook: <built-in function unraisablehook>
# Traceback (most recent call last):
#   File "C:\Users\prona\AppData\Local\Programs\Python\Python311\Lib\site-packages\ipykernel\iostream.py", line 575, in flush
#   File "C:\Users\prona\AppData\Local\Temp\ipykernel_45080\1506783316.py", line 12, in get_data
#     self._event_pipe.send(b"")
#     ^^^^^^^^^^^^^^^^
#   File "C:\Users\prona\AppData\Local\Programs\Python\Python311\Lib\site-packages\ipykernel\iostream.py", line 145, in _event_pipe
#   File "C:\Users\prona\AppData\Local\Programs\Python\Python311\Lib\site-packages\tdmclient\clientasynccachenode.py", line 78, in __getitem__
#   File "C:\Users\prona\AppData\Local\Temp\ipykernel_45080\134166037.py", line 12, in get_data
#   File "C:\Users\prona\AppData\Local\Temp\ipykernel_45080\1506783316.py", line 12, in get_data
#   File "C:\Users\prona\AppData\Local\Temp\ipykernel_45080\1143550603.py", line 12, in get_data
#     self.pub_thread.schedule(self._flush)
#   File "C:\Users\prona\AppData\Local\Programs\Python\Python311\Lib\site-packages\ipykernel\iostream.py", line 267, in schedule
#   File "C:\Users\prona\AppData\Local\Temp\ipykernel_45080\1506783316.py", line 12, in get_data
#     event_pipe = ctx.socket(zmq.PUSH)
#                  ^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\prona\AppData\Local\Programs\Python\Python311\Lib\site-packages\zmq\sugar\context.py", line 362, in socket
#     v = self.var[key]
#         ~~~~~~~~^^^^^
# KeyError: 'motor.left.speed'
# Exception in threading.excepthook:
# Exception ignored in thread started by: <bound method Thread._bootstrap of <Timer(Thread-583243, started 25156)>>
# Traceback (most recent call last):
#   File "C:\Users\prona\AppData\Local\Programs\Python\Python311\Lib\threading.py", line 1002, in _bootstrap
# zmq.error.ZMQError: Too many open files
# Exception ignored in sys.unraisablehook: <built-in function unraisablehook>
# Traceback (most recent call last):
#   File "C:\Users\prona\AppData\Local\Programs\Python\Python311\Lib\site-packages\ipykernel\iostream.py", line 575, in flush
#   File "C:\Users\prona\AppData\Local\Programs\Python\Python311\Lib\site-packages\tdmclient\clientasynccachenode.py", line 78, in __getitem__
#   File "C:\Users\prona\AppData\Local\Temp\ipykernel_45080\134166037.py", line 12, in get_data
#   File "C:\Users\prona\AppData\Local\Programs\Python\Python311\Lib\site-packages\tdmclient\clientasynccachenode.py", line 78, in __getitem__
#   File "C:\Users\prona\AppData\Local\Programs\Python\Python311\Lib\site-packages\tdmclient\clientasynccachenode.py", line 78, in __getitem__
#     v = self.var[key]
#         ~~~~~~~~^^^^^
# KeyError: 'motor.left.speed'
# Exception in threading.excepthook:
# Exception ignored in thread started by: <bound method Thread._bootstrap of <Timer(Thread-583242, started 54620)>>
# Traceback (most recent call last):
#   File "C:\Users\prona\AppData\Local\Programs\Python\Python311\Lib\threading.py", line 1002, in _bootstrap
#     self._event_pipe.send(b"")
#     ^^^^^^^^^^^^^^^^
#   File "C:\Users\prona\AppData\Local\Programs\Python\Python311\Lib\site-packages\ipykernel\iostream.py", line 145, in _event_pipe
#     v = self.var[key]
#         ~~~~~~~~^^^^^
# KeyError: 'motor.left.speed'
# Exception in threading.excepthook:
# Exception ignored in thread started by: <bound method Thread._bootstrap of <Timer(Thread-583247, started 82408)>>
# Traceback (most recent call last):
# ...
#   File "C:\Users\prona\AppData\Local\Programs\Python\Python311\Lib\site-packages\tdmclient\clientasynccachenode.py", line 78, in __getitem__
#     v = self.var[key]
#         ~~~~~~~~^^^^^
# KeyError: 'motor.left.speed'
#     v = self.var[key]
#         ~~~~~~~~^^^^^
# KeyError: 'motor.left.speed'
#     self.function(*self.args, **self.kwargs)
#   File "C:\Users\prona\AppData\Local\Temp\ipykernel_45080\4043924853.py", line 16, in _run
#     self.function(*self.args, **self.kwargs)
#   File "C:\Users\prona\AppData\Local\Temp\ipykernel_45080\4043924853.py", line 16, in _run
#     self.function(*self.args, **self.kwargs)
#   File "C:\Users\prona\AppData\Local\Temp\ipykernel_45080\4043924853.py", line 16, in _run
#     v = self.var[key]
#         ~~~~~~~~^^^^^
# KeyError: 'motor.left.speed'
#     v = self.var[key]
#         ~~~~~~~~^^^^^
# KeyError: 'motor.left.speed'
#     self.function(*self.args, **self.kwargs)
#   File "C:\Users\prona\AppData\Local\Temp\ipykernel_45080\4043924853.py", line 16, in _run
#   File "C:\Users\prona\AppData\Local\Temp\ipykernel_45080\134166037.py", line 12, in get_data
#   File "C:\Users\prona\AppData\Local\Temp\ipykernel_45080\1506783316.py", line 12, in get_data
#   File "C:\Users\prona\AppData\Local\Temp\ipykernel_45080\1506783316.py", line 12, in get_data
#   File "C:\Users\prona\AppData\Local\Programs\Python\Python311\Lib\site-packages\tdmclient\clientasynccachenode.py", line 78, in __getitem__
#   File "C:\Users\prona\AppData\Local\Temp\ipykernel_45080\134166037.py", line 12, in get_data
#   File "C:\Users\prona\AppData\Local\Programs\Python\Python311\Lib\site-packages\tdmclient\clientasynccachenode.py", line 78, in __getitem__
#     v = self.var[key]
#         ~~~~~~~~^^^^^
# KeyError: 'motor.left.speed'
#   File "C:\Users\prona\AppData\Local\Programs\Python\Python311\Lib\site-packages\tdmclient\clientasynccachenode.py", line 78, in __getitem__
#     v = self.var[key]
#         ~~~~~~~~^^^^^
# KeyError: 'motor.left.speed'
#   File "C:\Users\prona\AppData\Local\Programs\Python\Python311\Lib\site-packages\tdmclient\clientasynccachenode.py", line 78, in __getitem__
#     v = self.var[key]
#         ~~~~~~~~^^^^^
# KeyError: 'motor.left.speed'
#     v = self.var[key]
#         ~~~~~~~~^^^^^
# KeyError: 'motor.left.speed'
# Exception in thread Exception in thread Thread-584026:
# Traceback (most recent call last):
#   File "C:\Users\prona\AppData\Local\Programs\Python\Python311\Lib\threading.py", line 1045, in _bootstrap_inner
# Exception in thread Thread-584029:
# Traceback (most recent call last):
#   File "C:\Users\prona\AppData\Local\Programs\Python\Python311\Lib\threading.py", line 1045, in _bootstrap_inner
# Exception in thread Thread-584022:
# Traceback (most recent call last):
#   File "C:\Users\prona\AppData\Local\Programs\Python\Python311\Lib\threading.py", line 1045, in _bootstrap_inner
# Thread-584028:
# Traceback (most recent call last):
#   File "C:\Users\prona\AppData\Local\Programs\Python\Python311\Lib\threading.py", line 1045, in _bootstrap_inner
# Exception in thread Thread-584027:
# Traceback (most recent call last):
#   File "C:\Users\prona\AppData\Local\Programs\Python\Python311\Lib\threading.py", line 1045, in _bootstrap_inner
# Exception in thread Thread-584024:
# Traceback (most recent call last):
#   File "C:\Users\prona\AppData\Local\Programs\Python\Python311\Lib\threading.py", line 1045, in _bootstrap_inner
# Exception in thread Thread-584025:
# Traceback (most recent call last):
#   File "C:\Users\prona\AppData\Local\Programs\Python\Python311\Lib\threading.py", line 1045, in _bootstrap_inner
#     self.run()
#   File "C:\Users\prona\AppData\Local\Programs\Python\Python311\Lib\threading.py", line 1401, in run
#     self.run()
#   File "C:\Users\prona\AppData\Local\Programs\Python\Python311\Lib\threading.py", line 1401, in run
#     self.run()
#   File "C:\Users\prona\AppData\Local\Programs\Python\Python311\Lib\threading.py", line 1401, in run
# Exception in thread Thread-584023:
# Traceback (most recent call last):
#   File "C:\Users\prona\AppData\Local\Programs\Python\Python311\Lib\threading.py", line 1045, in _bootstrap_inner
#     self.run()
#   File "C:\Users\prona\AppData\Local\Programs\Python\Python311\Lib\threading.py", line 1401, in run
#     self.run()
#   File "C:\Users\prona\AppData\Local\Programs\Python\Python311\Lib\threading.py", line 1401, in run
#     self.run()
#   File "C:\Users\prona\AppData\Local\Programs\Python\Python311\Lib\threading.py", line 1401, in run
#     self.function(*self.args, **self.kwargs)
#   File "C:\Users\prona\AppData\Local\Temp\ipykernel_45080\4043924853.py", line 16, in _run
#     self.run()
#   File "C:\Users\prona\AppData\Local\Programs\Python\Python311\Lib\threading.py", line 1401, in run
#     self.run()
#   File "C:\Users\prona\AppData\Local\Programs\Python\Python311\Lib\threading.py", line 1401, in run
#     self.function(*self.args, **self.kwargs)
#   File "C:\Users\prona\AppData\Local\Temp\ipykernel_45080\4043924853.py", line 16, in _run
#     self.function(*self.args, **self.kwargs)
#   File "C:\Users\prona\AppData\Local\Temp\ipykernel_45080\4043924853.py", line 16, in _run
#     self.function(*self.args, **self.kwargs)
#   File "C:\Users\prona\AppData\Local\Temp\ipykernel_45080\4043924853.py", line 16, in _run
#     self.function(*self.args, **self.kwargs)
#   File "C:\Users\prona\AppData\Local\Temp\ipykernel_45080\4043924853.py", line 16, in _run
#   File "C:\Users\prona\AppData\Local\Temp\ipykernel_45080\1506783316.py", line 12, in get_data
#     self.function(*self.args, **self.kwargs)
#   File "C:\Users\prona\AppData\Local\Temp\ipykernel_45080\4043924853.py", line 16, in _run
#     self.function(*self.args, **self.kwargs)
#   File "C:\Users\prona\AppData\Local\Temp\ipykernel_45080\4043924853.py", line 16, in _run
#   File "C:\Users\prona\AppData\Local\Temp\ipykernel_45080\1506783316.py", line 12, in get_data
#   File "C:\Users\prona\AppData\Local\Temp\ipykernel_45080\1143550603.py", line 12, in get_data
# Exception in thread Thread-584033:
# Traceback (most recent call last):
#   File "C:\Users\prona\AppData\Local\Programs\Python\Python311\Lib\threading.py", line 1045, in _bootstrap_inner
#   File "C:\Users\prona\AppData\Local\Temp\ipykernel_45080\134166037.py", line 12, in get_data
#     self.function(*self.args, **self.kwargs)
#   File "C:\Users\prona\AppData\Local\Temp\ipykernel_45080\4043924853.py", line 16, in _run
#   File "C:\Users\prona\AppData\Local\Temp\ipykernel_45080\1506783316.py", line 12, in get_data
# Exception in thread Thread-584031:
# Traceback (most recent call last):
#   File "C:\Users\prona\AppData\Local\Programs\Python\Python311\Lib\threading.py", line 1045, in _bootstrap_inner
#   File "C:\Users\prona\AppData\Local\Programs\Python\Python311\Lib\site-packages\tdmclient\clientasynccachenode.py", line 78, in __getitem__
#   File "C:\Users\prona\AppData\Local\Temp\ipykernel_45080\1143550603.py", line 12, in get_data
# Exception in thread Thread-584032:
# Traceback (most recent call last):
#   File "C:\Users\prona\AppData\Local\Programs\Python\Python311\Lib\threading.py", line 1045, in _bootstrap_inner
# Exception in thread Thread-584030:
# Traceback (most recent call last):
#   File "C:\Users\prona\AppData\Local\Programs\Python\Python311\Lib\threading.py", line 1045, in _bootstrap_inner
#   File "C:\Users\prona\AppData\Local\Programs\Python\Python311\Lib\site-packages\tdmclient\clientasynccachenode.py", line 78, in __getitem__
#     v = self.var[key]
#         ~~~~~~~~^^^^^
# KeyError: 'motor.left.speed'
#   File "C:\Users\prona\AppData\Local\Temp\ipykernel_45080\1143550603.py", line 12, in get_data
#     self.run()
#   File "C:\Users\prona\AppData\Local\Programs\Python\Python311\Lib\threading.py", line 1401, in run
#     v = self.var[key]
#         ~~~~~~~~^^^^^
# KeyError: 'motor.left.speed'
#   File "C:\Users\prona\AppData\Local\Programs\Python\Python311\Lib\site-packages\tdmclient\clientasynccachenode.py", line 78, in __getitem__
#     self.run()
#   File "C:\Users\prona\AppData\Local\Programs\Python\Python311\Lib\threading.py", line 1401, in run
#   File "C:\Users\prona\AppData\Local\Programs\Python\Python311\Lib\site-packages\tdmclient\clientasynccachenode.py", line 78, in __getitem__
#   File "C:\Users\prona\AppData\Local\Temp\ipykernel_45080\1506783316.py", line 12, in get_data
#     v = self.var[key]
#         ~~~~~~~~^^^^^
# KeyError: 'motor.left.speed'
#   File "C:\Users\prona\AppData\Local\Programs\Python\Python311\Lib\site-packages\tdmclient\clientasynccachenode.py", line 78, in __getitem__
#     v = self.var[key]
#         ~~~~~~~~^^^^^
# KeyError: 'motor.left.speed'
#   File "C:\Users\prona\AppData\Local\Programs\Python\Python311\Lib\site-packages\tdmclient\clientasynccachenode.py", line 78, in __getitem__
#     self.run()
#   File "C:\Users\prona\AppData\Local\Programs\Python\Python311\Lib\threading.py", line 1401, in run
#     self.run()
#   File "C:\Users\prona\AppData\Local\Programs\Python\Python311\Lib\threading.py", line 1401, in run
#     v = self.var[key]
#         ~~~~~~~~^^^^^
# KeyError: 'motor.left.speed'
#   File "C:\Users\prona\AppData\Local\Programs\Python\Python311\Lib\site-packages\tdmclient\clientasynccachenode.py", line 78, in __getitem__
#     v = self.var[key]
#         ~~~~~~~~^^^^^
# KeyError: 'motor.left.speed'
#   File "C:\Users\prona\AppData\Local\Programs\Python\Python311\Lib\site-packages\tdmclient\clientasynccachenode.py", line 78, in __getitem__
#     self.function(*self.args, **self.kwargs)
#   File "C:\Users\prona\AppData\Local\Temp\ipykernel_45080\4043924853.py", line 16, in _run
#     self.function(*self.args, **self.kwargs)
#   File "C:\Users\prona\AppData\Local\Temp\ipykernel_45080\4043924853.py", line 16, in _run
#     self.function(*self.args, **self.kwargs)
#   File "C:\Users\prona\AppData\Local\Temp\ipykernel_45080\4043924853.py", line 16, in _run
#     v = self.var[key]
#         ~~~~~~~~^^^^^
# KeyError: 'motor.left.speed'
#     self.function(*self.args, **self.kwargs)
#   File "C:\Users\prona\AppData\Local\Temp\ipykernel_45080\4043924853.py", line 16, in _run
#     v = self.var[key]
#         ~~~~~~~~^^^^^
# KeyError: 'motor.left.speed'
#   File "C:\Users\prona\AppData\Local\Temp\ipykernel_45080\1506783316.py", line 12, in get_data
#   File "C:\Users\prona\AppData\Local\Temp\ipykernel_45080\134166037.py", line 12, in get_data
#   File "C:\Users\prona\AppData\Local\Temp\ipykernel_45080\134166037.py", line 12, in get_data
#   File "C:\Users\prona\AppData\Local\Temp\ipykernel_45080\1506783316.py", line 12, in get_data
#   File "C:\Users\prona\AppData\Local\Programs\Python\Python311\Lib\site-packages\tdmclient\clientasynccachenode.py", line 78, in __getitem__
#   File "C:\Users\prona\AppData\Local\Programs\Python\Python311\Lib\site-packages\tdmclient\clientasynccachenode.py", line 78, in __getitem__
#   File "C:\Users\prona\AppData\Local\Programs\Python\Python311\Lib\site-packages\tdmclient\clientasynccachenode.py", line 78, in __getitem__
#   File "C:\Users\prona\AppData\Local\Programs\Python\Python311\Lib\site-packages\tdmclient\clientasynccachenode.py", line 78, in __getitem__
#     v = self.var[key]
#         ~~~~~~~~^^^^^
# KeyError: 'motor.left.speed'
#     v = self.var[key]
#         ~~~~~~~~^^^^^
# KeyError: 'motor.left.speed'
#     v = self.var[key]
#         ~~~~~~~~^^^^^
# KeyError: 'motor.left.speed'
#     v = self.var[key]
#         ~~~~~~~~^^^^^
# KeyError: 'motor.left.speed'
# Exception in thread Exception in thread Thread-584038:
# Traceback (most recent call last):
#   File "C:\Users\prona\AppData\Local\Programs\Python\Python311\Lib\threading.py", line 1045, in _bootstrap_inner
# Exception in thread Thread-584039:
# Traceback (most recent call last):
#   File "C:\Users\prona\AppData\Local\Programs\Python\Python311\Lib\threading.py", line 1045, in _bootstrap_inner
# Exception in thread Thread-584034:
# Traceback (most recent call last):
#   File "C:\Users\prona\AppData\Local\Programs\Python\Python311\Lib\threading.py", line 1045, in _bootstrap_inner
# Exception in thread Thread-584036:
# Traceback (most recent call last):
#   File "C:\Users\prona\AppData\Local\Programs\Python\Python311\Lib\threading.py", line 1045, in _bootstrap_inner
# Thread-584037:
# Traceback (most recent call last):
#   File "C:\Users\prona\AppData\Local\Programs\Python\Python311\Lib\threading.py", line 1045, in _bootstrap_inner
# Exception in thread Thread-584040:
# Traceback (most recent call last):
#   File "C:\Users\prona\AppData\Local\Programs\Python\Python311\Lib\threading.py", line 1045, in _bootstrap_inner
# Exception in thread Thread-584035:
# Traceback (most recent call last):
#   File "C:\Users\prona\AppData\Local\Programs\Python\Python311\Lib\threading.py", line 1045, in _bootstrap_inner
#     self.run()
#   File "C:\Users\prona\AppData\Local\Programs\Python\Python311\Lib\threading.py", line 1401, in run
#     self.run()
#   File "C:\Users\prona\AppData\Local\Programs\Python\Python311\Lib\threading.py", line 1401, in run
#     self.run()
#   File "C:\Users\prona\AppData\Local\Programs\Python\Python311\Lib\threading.py", line 1401, in run
#     self.run()
#   File "C:\Users\prona\AppData\Local\Programs\Python\Python311\Lib\threading.py", line 1401, in run
#     self.run()
#   File "C:\Users\prona\AppData\Local\Programs\Python\Python311\Lib\threading.py", line 1401, in run
#     self.function(*self.args, **self.kwargs)
#   File "C:\Users\prona\AppData\Local\Temp\ipykernel_45080\4043924853.py", line 16, in _run
# Exception in thread Thread-584042:
# Traceback (most recent call last):
#   File "C:\Users\prona\AppData\Local\Programs\Python\Python311\Lib\threading.py", line 1045, in _bootstrap_inner
# Exception in thread Thread-584045:
# Traceback (most recent call last):
#   File "C:\Users\prona\AppData\Local\Programs\Python\Python311\Lib\threading.py", line 1045, in _bootstrap_inner
#     self.run()
#   File "C:\Users\prona\AppData\Local\Programs\Python\Python311\Lib\threading.py", line 1401, in run
# Exception in thread Thread-584043:
# Traceback (most recent call last):
#   File "C:\Users\prona\AppData\Local\Programs\Python\Python311\Lib\threading.py", line 1045, in _bootstrap_inner
# Exception in thread Thread-584041:
# Traceback (most recent call last):
#   File "C:\Users\prona\AppData\Local\Programs\Python\Python311\Lib\threading.py", line 1045, in _bootstrap_inner
#     self.function(*self.args, **self.kwargs)
#   File "C:\Users\prona\AppData\Local\Temp\ipykernel_45080\4043924853.py", line 16, in _run
# Exception in thread Thread-584044:
# Traceback (most recent call last):
#   File "C:\Users\prona\AppData\Local\Programs\Python\Python311\Lib\threading.py", line 1045, in _bootstrap_inner
#     self.function(*self.args, **self.kwargs)
#   File "C:\Users\prona\AppData\Local\Temp\ipykernel_45080\4043924853.py", line 16, in _run
#     self.run()
#   File "C:\Users\prona\AppData\Local\Programs\Python\Python311\Lib\threading.py", line 1401, in run
#     self.run()
#   File "C:\Users\prona\AppData\Local\Programs\Python\Python311\Lib\threading.py", line 1401, in run
#     self.run()
#   File "C:\Users\prona\AppData\Local\Programs\Python\Python311\Lib\threading.py", line 1401, in run
#     self.run()
#   File "C:\Users\prona\AppData\Local\Programs\Python\Python311\Lib\threading.py", line 1401, in run
#     self.function(*self.args, **self.kwargs)
#   File "C:\Users\prona\AppData\Local\Temp\ipykernel_45080\4043924853.py", line 16, in _run
#     self.function(*self.args, **self.kwargs)
#   File "C:\Users\prona\AppData\Local\Temp\ipykernel_45080\4043924853.py", line 16, in _run
#     self.function(*self.args, **self.kwargs)
#   File "C:\Users\prona\AppData\Local\Temp\ipykernel_45080\4043924853.py", line 16, in _run
#     self.run()
#   File "C:\Users\prona\AppData\Local\Programs\Python\Python311\Lib\threading.py", line 1401, in run
#     self.function(*self.args, **self.kwargs)
#   File "C:\Users\prona\AppData\Local\Temp\ipykernel_45080\4043924853.py", line 16, in _run
#   File "C:\Users\prona\AppData\Local\Temp\ipykernel_45080\1143550603.py", line 12, in get_data
#   File "C:\Users\prona\AppData\Local\Temp\ipykernel_45080\134166037.py", line 12, in get_data
#     self.function(*self.args, **self.kwargs)
#   File "C:\Users\prona\AppData\Local\Temp\ipykernel_45080\4043924853.py", line 16, in _run
#     self.run()
#   File "C:\Users\prona\AppData\Local\Programs\Python\Python311\Lib\threading.py", line 1401, in run

# %%
@onevent
def angle_to_rotate(pos_i, pos_f, theta_i):
    a = pos_f-pos_i
    theta_f = np.arctan2(a[1], a[0])
    r_theta = (theta_f*180)/np.pi-theta_i
    return r_theta
    
pos_thymio = np.array([1,1])
pos_goal = np.array([30,45])
theta = angle_to_rotate(pos_thymio,pos_goal,0)
print(theta)
# Out:
# 56.61148642388849

# %%
@onevent
def distance_to_cover(pos_i, pos_f):
    distance = np.linalg.norm(pos_f-pos_i)
    return distance

pos_thymio = np.array([0,0])
pos_goal = np.array([30,45])
theta = angle_to_rotate(pos_thymio,pos_goal,0)
dist = distance_to_cover(pos_thymio,pos_goal)
print(dist)
# Out:
# 54.08326913195984

# %%
nb_node = 3
initial_orientation = 0 #degree
positions = np.array([[0,0],[30,45],[50,50],[17,15],[50,10]]);
rotations = np.zeros(positions.shape[0]-1)
distances =  np.zeros(positions.shape[0]-1)

rotations[0] = angle_to_rotate(positions[0],positions[1],initial_orientation)
orientation = initial_orientation+rotations[0]

for i in range(1,positions.shape[0]-1):
    rotations[i] = angle_to_rotate(positions[i],positions[i+1],orientation)
    distances[i-1] = distance_to_cover(positions[i-1],positions[i])
    orientation = orientation+rotations[i]

distances[distances.size-1]=distance_to_cover(positions[distances.size-1],positions[distances.size])

print('Rotations :',rotations)
print('Distances :',distances)
# Out:
# Rotations : [  56.30993247  -42.27368901 -147.35155915  124.6996675 ]
# Distances : [54.08326913 20.61552813 48.10405388 33.37663854]

# %%
print(3537/121)
# Out:
# 29.231404958677686

# %% [markdown]
# ## Async implementation:

# %%
from tdmclient import ClientAsync, aw
client = ClientAsync()
node = await client.wait_for_node()
await node.lock()
# Out:
# Node 0102d6c0-0c6c-479f-8406-474092b0daba

# %%
await node.wait_for_variables()
node.var

# %%
def angle_to_rotate(pos_i, pos_f, theta_i):
    a = pos_f-pos_i
    theta_f = np.arctan2(a[1], a[0])
    r_theta = (theta_f*180)/np.pi-theta_i
    return r_theta

def distance_to_cover(pos_i, pos_f):
    distance = np.linalg.norm(pos_f-pos_i)
    return distance

# %%
def path(positions, initial_orientation):
    nb_node = 3
    rotations = np.zeros(positions.shape[0]-1)
    distances =  np.zeros(positions.shape[0]-1)
    
    rotations[0] = angle_to_rotate(positions[0],positions[1],initial_orientation)
    orientation = initial_orientation+rotations[0]
    
    for i in range(1,positions.shape[0]-1):
        rotations[i] = angle_to_rotate(positions[i],positions[i+1],orientation)
        distances[i-1] = distance_to_cover(positions[i-1],positions[i])
        orientation = orientation+rotations[i]

    distances[distances.size-1]=distance_to_cover(positions[distances.size-1],positions[distances.size])
    rotation_ratios = rotations/360
    return distances, rotations, orientation, rotation_ratios

# %% [markdown]
# <strong>Kalman filter :

# %%
from threading import Timer

class RepeatedTimer(object):
    def __init__(self, interval, function, *args, **kwargs):
        self._timer     = None
        self.interval   = interval
        self.function   = function
        self.args       = args
        self.kwargs     = kwargs
        self.is_running = False
        self.start()

    def _run(self):
        self.is_running = False
        self.start()
        self.function(*self.args, **self.kwargs)

    def start(self):
        if not self.is_running:
            self._timer = Timer(self.interval, self._run)
            self._timer.start()
            self.is_running = True

    def stop(self):
        self._timer.cancel()
        self.is_running = False

# %%
import matplotlib.pyplot as plt
from scipy.signal import find_peaks
import numpy as np
from tqdm import tqdm

# %% [markdown]
# <strong> Variance for position :

# %%
qpx = 0.04 # variance on position state
qpy = 0.04
rpx = 0.25 # variance on position measurement 
rpy = 0.25

qpx = 0.04 # variance on position state
qpy = 0.04 
rpx = 0.25 # variance on position measurement 
rpy = 0.25

# %% [markdown]
# <strong>Variance for angle :

# %%
std_speed = 11.77
q_theta_nu = std_speed/2 # variance on speed state
r_theta_nu = std_speed/2 # variance on speed measurement 

print(q_theta_nu,r_theta_nu)
# Out:
# 5.885 5.885

# %%
# Initialising the remaining constants
# units: length [mm], time [s]
A = np.array([[1, 0, 0], [0, 1, 0], [0, 0, 1]])
Q = np.array([[qpx, 0, 0], [0, qpy, 0],[0, 0, q_theta_nu]]); #w matrix
rotation_conv_factor = 0.41; #0.8 for 50 speed, 0.41 for 100 speed
speed_conv_factor_straight = 0.338; #straight
speed_conv_factor_left = 0.403;
speed_conv_factor_right = 0.425;

speed_conv_factor = 0.374 #mean of the two
transition_thresh = 500
l = 100 #mm, distance between the two wheels

def kalman_filter( x_est_prev, P_est_prev, Vr, Vl, Ts, camera_x=0, camera_y=0, camera_angle=0,):

    ## Prediciton through the a priori estimate
    # estimated mean of the state
    if abs(Vr-Vl) < 30:
        speed_conv_factor = speed_conv_factor_straight
    elif Vr<Vl:
        speed_conv_factor = speed_conv_factor_right
    else:
        speed_conv_factor = speed_conv_factor_left
    
    
    orientation = np.double(x_est_prev[2][0]%360)*2*np.pi/360
    #x_est_prev[2][0] = orientation
    B = np.array([[Ts*np.cos(orientation)/2,Ts*np.cos(orientation)/2],
         [Ts*np.sin(orientation)/2,Ts*np.sin(orientation)/2],
         [-Ts*360/(l*2*np.pi), Ts*360/(l*2*np.pi)]])
    U = np.array([[Vr*speed_conv_factor],[Vl*speed_conv_factor]])
    x_est_a_priori = np.dot(A, x_est_prev) + np.dot(B, U);
  
    
    # Estimated covariance of the state
    P_est_a_priori = np.dot(A, np.dot(P_est_prev, A.T));
    P_est_a_priori = P_est_a_priori + Q if type(Q) != type(None) else P_est_a_priori
    
    ## Update         
    # y, C, and R for a posteriori estimate, depending on transition
    if (camera_x != 0) : #XOR (one or the other but not both)
        # transition detected aka camera provides the position
        y = np.array([[camera_x],[camera_y],[camera_angle]])
        H = np.array([[1, 0, 0],[0, 1, 0],[0, 0, 1]])
        R = np.array([[rpx, 0, 0],[0, rpy,0],[0, 0, r_theta_nu]]) #not the value of the variance of the position measurments
        
        # innovation / measurement residual
        i = y - np.dot(H, x_est_a_priori); #measured-mean aka difference between the two states
        # measurement prediction covariance
        S = np.dot(H, np.dot(P_est_a_priori, H.T)) + R;
                 
        # Kalman gain (tells how much the predictions should be corrected based on the measurements)
        K = np.dot(P_est_a_priori, np.dot(H.T, np.linalg.inv(S)));
            
        # a posteriori estimate
        x_est = x_est_a_priori + np.dot(K,i);
        P_est = P_est_a_priori - np.dot(K,np.dot(H, P_est_a_priori));

    else:
        x_est = x_est_a_priori
        P_est = P_est_a_priori
     
    return x_est, P_est

# %% [markdown]
# Test of the filter

# %%
#test of the kalman filter
x_est = np.array([[0], [0], [0]]) # in mm !!!
#P_est = [1000 * np.ones(2)]

P_est = 0
Vr = 100;
Vl = 100;

Ts = 0.1

camera_x = 4
camera_y = 0
camera_angle = 0

#for i in range(0,20):
new_x_est, new_P_est = kalman_filter(x_est, P_est, Vr, Vl, Ts, camera_x=0, camera_y=0, camera_angle=0);
x_est = new_x_est;
P_est = new_P_est;

print(x_est[2][0])
print("new_x_est\n",new_x_est,"\n new_P_est\n", new_P_est)
# Out:
# 8.69733149685918e-17
# new_x_est
#  [[3.7400000e+00]
#  [0.0000000e+00]
#  [8.6973315e-17]]
#  new_P_est
#  [[0.04  0.    0.   ]
#  [0.    0.04  0.   ]
#  [0.    0.    5.885]]

# %%
import time

# %%
thymio_data = []
initial_orientation = 0 #degree
positions = np.array([[0,0],[200,150],[10,30]])#[0,0],[30,45],[50,50],[17,15],[50,10]
angle_threshold = 5 #degrees
x_est = np.array([[positions[0][0]], [positions[0][1]], [initial_orientation]])
P_est = 0
Ts = 0.05
count = 0
read = 1
Vr = 0
Vl = 0
position_threshold = 10


async def main():    

    global x_est, P_est, Ts, read, Vr, Vl
    n = 1
    await node.wait_for_variables() # wait for Thymio variables values
    rt = RepeatedTimer(Ts, filter)#, x_est, P_est, Ts)
    
    try:
        for i in range(0,50):
            start = time.time()
            if (positions[n][0]+position_threshold > x_est[0][0]) and (positions[n][0]-position_threshold < x_est[0][0]):
                if (positions[n][1]+position_threshold > x_est[1][0]) and (positions[n][1]-position_threshold < x_est[1][0]):
                    n+=1
            angle = angle_to_rotate([x_est[0][0],x_est[1][0]],positions[n],x_est[2][0]);
            if (abs(angle)<angle_threshold):
                #Vr = 100
                #Vl = 100
                drive_task = asyncio.create_task(drive_for_seconds(client, Ts))
                await drive_task
    
            else:
                if angle>0:
                    right = 1
                    #Vr = -100
                    #Vl = 100
                else:
                    right = 0
                    #Vr = 100
                    #Vl = -100

                turn_task = asyncio.create_task(turn_for_seconds(client, Ts, right))
                await turn_task
            #print(x_est)
            stop = time.time()
            print("time elapsed : ", start - stop)
    finally:
        rt.stop()
        node.send_set_variables(motors(0, 0))

await main()
# Out:
# [[-0.06045   ]
#  [ 0.        ]
#  [-2.14738852]]
# [[-5.20059341e-02]
#  [-3.16623412e-04]
#  [-2.13770553e+00]]
# [[-5.20059341e-02]
#  [-3.16623412e-04]
#  [-2.13770553e+00]]
# [[-8.57824114e-02]
#  [ 9.44162030e-04]
#  [-2.17643748e+00]]
# [[-8.57824114e-02]
#  [ 9.44162030e-04]
#  [-2.17643748e+00]]
# [[-0.12800193]
#  [ 0.00254868]
#  [-2.22485241]]
# [[-0.17022008]
#  [ 0.00418888]
#  [-2.27326735]]
# [[-0.17022008]
#  [ 0.00418888]
#  [-2.27326735]]
# [[-0.17022008]
#  [ 0.00418888]
#  [-2.27326735]]
# [[-0.17022008]
#  [ 0.00418888]
#  [-2.27326735]]
# [[-0.19555013]
#  [ 0.0051944 ]
#  [-2.30231631]]
# [[-0.22932285]
#  [ 0.00655222]
#  [-2.34104826]]
# [[-0.22932285]
#  [ 0.00655222]
#  [-2.34104826]]
# [[-0.22932285]
#  [ 0.00655222]
#  [-2.34104826]]
# [[-0.27153759]
#  [ 0.00827804]
#  [-2.38946319]]
# [[-0.27153759]
#  [ 0.00827804]
#  [-2.38946319]]
# [[-0.28842289]
#  [ 0.00898263]
#  [-2.37009722]]
# [[-0.33063675]
#  [ 0.01072985]
#  [-2.41851215]]
# [[-0.33063675]
#  [ 0.01072985]
#  [-2.41851215]]
# [[-0.35596417]
#  [ 0.01179958]
#  [-2.44756111]]
# [[-0.35596417]
#  [ 0.01179958]
#  [-2.44756111]]
# [[-0.35596417]
#  [ 0.01179958]
#  [-2.44756111]]
# [[-0.31350294]
#  [ 0.00998461]
#  [-0.0855426 ]]
# time elapsed :  -1.9783518314361572
# [[-0.27100299]
#  [ 0.00992116]
#  [ 2.27647591]]
# [[-0.22853653]
#  [ 0.01160933]
#  [ 4.63849442]]
# [[-4.40340544e-01]
#  [-5.57524961e-03]
#  [ 7.36577353e+00]]
# time elapsed :  -0.16677594184875488
# [[-0.65108698]
#  [-0.03281843]
#  [10.09305263]]
# [[-0.69292927]
#  [-0.04026644]
#  [12.50377255]]
# time elapsed :  -0.1673431396484375
# [[-0.73442124]
#  [-0.04946785]
#  [14.91449248]]
# [[-0.77548946]
#  [-0.06040639]
#  [17.3252124 ]]
# [[-0.70448886]
#  [-0.03825788]
#  [19.74810768]]
# time elapsed :  -0.16642355918884277
# [[-6.34488067e-01]
#  [-1.31276407e-02]
#  [ 2.21710030e+01]]
# [[-5.65612229e-01]
#  [ 1.49394138e-02]
#  [ 2.45938982e+01]]
# [[-6.04256648e-01]
#  [-2.74840452e-03]
#  [ 2.70776703e+01]]
# time elapsed :  -0.1669025421142578
# [[-6.42098234e-01]
#  [-2.20943166e-02]
#  [ 2.95614423e+01]]
# [[-0.67906589]
#  [-0.04306197]
#  [32.04521435]]
# [[-6.16023432e-01]
#  [-3.59946618e-03]
#  [ 3.47359674e+01]]
# time elapsed :  -0.16594362258911133
# [[-0.55490306]
#  [ 0.03877908]
#  [37.42672045]]
# [[-6.13966574e-01]
#  [-6.42205283e-03]
#  [ 3.98009143e+01]]
# time elapsed :  -0.16665911674499512
# [[-0.6711069 ]
#  [-0.05403112]
#  [42.17510817]]
# [[-0.72622594]
#  [-0.1039664 ]
#  [44.54930204]]
# [[ 0.33383657]
#  [ 0.93954868]
#  [45.15806969]]
# time elapsed :  -0.16617298126220703
# [[ 1.3827521 ]
#  [ 1.99426782]
#  [45.76683735]]
# [[ 2.42040225]
#  [ 3.06007193]
#  [46.37560501]]
# [[ 3.47561235]
#  [ 4.16720741]
#  [46.54021578]]
# time elapsed :  -0.1677560806274414
# [[ 4.52763729]
#  [ 5.27736993]
#  [46.70482656]]
# [[ 5.5764684 ]
#  [ 6.39055033]
#  [46.86943733]]
# [[ 5.87264837]
#  [ 6.70671694]
#  [44.80286451]]
# time elapsed :  -0.1653609275817871
# [[ 6.18003689]
#  [ 7.01199746]
#  [42.73629169]]
# [[ 6.23923637]
#  [ 7.06669464]
#  [40.58890316]]
# time elapsed :  -0.1666250228881836
# [[ 6.3004438 ]
#  [ 7.11913519]
#  [38.44151464]]
# [[ 6.3635732 ]
#  [ 7.16924545]
#  [36.29412612]]
# [[ 7.16748675]
#  [ 7.75965178]
#  [35.12807107]]
# time elapsed :  -0.1664571762084961
# [[ 7.98324864]
#  [ 8.33357614]
#  [33.96201601]]
# [[ 8.81052102]
#  [ 8.8907808 ]
#  [32.79596095]]
# [[10.03935913]
#  [ 9.68259033]
#  [32.61198421]]
# time elapsed :  -0.16886448860168457
# [[11.27073341]
#  [10.47044997]
#  [32.42800746]]
# [[12.50463114]
#  [11.25435162]
#  [32.24403071]]
# [[13.8410958 ]
#  [12.09740337]
#  [32.06005396]]
# time elapsed :  -0.16677236557006836
# [[15.1802606 ]
#  [12.93615939]
#  [31.87607721]]
# [[16.60104416]
#  [13.81969642]
#  [31.7405154 ]]
# time elapsed :  -0.16592955589294434
# [[18.02391419]
#  [14.69986941]
#  [31.60495359]]
# [[19.44886272]
#  [15.57667343]
#  [31.46939177]]
# [[21.01281796]
#  [16.53391757]
#  [31.44034281]]
# time elapsed :  -0.166778564453125
# [[22.57725831]
#  [17.49036866]
#  [31.41129385]]
# [[24.14218339]
#  [18.44602646]
#  [31.38224489]]
# [[24.80434392]
#  [18.84992938]
#  [32.80676121]]
# time elapsed :  -0.1660621166229248
# [[25.45625881]
#  [19.27016875]
#  [34.23127753]]
# [[26.09752509]
#  [19.7064848 ]
#  [35.65579384]]
# [[26.39105282]
#  [19.91706265]
#  [37.57949964]]
# time elapsed :  -0.16544795036315918
# [[26.6773463 ]
#  [20.13737517]
#  [39.50320544]]
# [[27.77921397]
#  [21.04578832]
#  [39.60971829]]
# time elapsed :  -0.16722774505615234
# [[28.87939099]
#  [21.95624827]
#  [39.71623115]]
# [[29.97787357]
#  [22.86875187]
#  [39.822744  ]]
# [[31.21094472]
#  [23.89693756]
#  [39.84210997]]
# time elapsed :  -0.16660189628601074
# [[32.44366827]
#  [24.92553995]
#  [39.86147595]]
# [[33.67604408]
#  [25.95455896]
#  [39.88084192]]
# [[35.07666531]
#  [27.12486456]
#  [39.66781621]]
# time elapsed :  -0.15195584297180176
# [[36.48162805]
#  [28.28995458]
#  [39.45479051]]
# [[37.74085013]
#  [29.32630947]
#  [39.36764362]]
# time elapsed :  -0.1662602424621582
# [[39.00164705]
#  [30.36074789]
#  [39.28049674]]
# [[40.2640159 ]
#  [31.39326744]
#  [39.19334986]]
# [[41.50175814]
#  [32.40250619]
#  [39.12556896]]
# time elapsed :  -0.16710138320922852
# [[42.74069345]
#  [33.41027998]
#  [39.05778805]]
# [[43.98082008]
#  [34.4165874 ]
#  [38.99000714]]
# [[45.44544188]
#  [35.60219185]
#  [39.0190561 ]]
# time elapsed :  -0.16595077514648438
# [[46.90946238]
#  [36.78853872]
#  [39.04810506]]
# [[48.37288122]
#  [37.97562769]
#  [39.07715402]]
# [[49.64546623]
#  [39.0089872 ]
#  [39.05778805]]
# time elapsed :  -0.16798043251037598
# [[50.91840045]
#  [40.04191651]
#  [39.03842208]]
# [[52.23106362]
#  [41.10634847]
#  [39.13525194]]
# time elapsed :  -0.1667191982269287
# [[53.54192603]
#  [42.17299731]
#  [39.23208181]]
# [[54.85098393]
#  [43.24185999]
#  [39.32891168]]
# [[56.07326236]
#  [44.24331367]
#  [39.31922869]]
# time elapsed :  -0.16782617568969727
# [[57.29571001]
#  [45.24456077]
#  [39.3095457 ]]
# [[58.51832686]
#  [46.24560126]
#  [39.29986272]]
# [[59.78034664]
#  [47.27854743]
#  [39.21271584]]
# time elapsed :  -0.16864871978759766
# [[61.04393607]
#  [48.30957288]
#  [39.12556896]]
# [[62.30909223]
#  [49.33867521]
#  [39.03842208]]
# [[63.77927498]
#  [50.53083901]
#  [39.05778805]]
# time elapsed :  -0.1674518585205078
# [[65.2490547 ]
#  [51.72349966]
#  [39.07715402]]
# [[66.56755773]
#  [52.79414533]
#  [39.02873909]]
# time elapsed :  -0.1667184829711914
# [[67.88696498]
#  [53.86367649]
#  [38.98032416]]
# [[69.20727552]
#  [54.93209236]
#  [38.93190922]]
# [[70.5219152 ]
#  [55.99408225]
#  [38.89317727]]
# time elapsed :  -0.16643524169921875
# [[71.83727249]
#  [57.05518319]
#  [38.85444533]]
# [[73.15334678]
#  [58.11539471]
#  [38.81571338]]
# [[74.3384584 ]
#  [59.06878416]
#  [38.99000714]]
# time elapsed :  -0.15282630920410156
# [[75.52066433]
#  [60.0257743 ]
#  [39.1643009 ]]
# [[76.79167614]
#  [61.06106821]
#  [39.20303285]]
# time elapsed :  -0.16661548614501953
# [[78.06198779]
#  [62.09722109]
#  [39.2417648 ]]
# [[79.33159872]
#  [63.13423247]
#  [39.28049674]]
# [[80.56780448]
#  [64.14535265]
#  [39.27081376]]
# time elapsed :  -0.166945219039917
# [[81.8041811 ]
#  [65.1562639 ]
#  [39.26113077]]
# [[83.04072855]
#  [66.16696618]
#  [39.25144778]]
# [[84.24472937]
#  [67.15072685]
#  [39.27081376]]
# time elapsed :  -0.16710448265075684
# [[85.44839762]
#  [68.13489442]
#  [39.29017973]]
# [[86.65173314]
#  [69.11946876]
#  [39.3095457 ]]
# [[87.99203504]
#  [70.2168661 ]
#  [39.28049674]]
# time elapsed :  -0.1667313575744629
# [[89.33289313]
#  [71.31358375]
#  [39.25144778]]
# [[91.1897322 ]
#  [72.83076315]
#  [38.7434634 ]]
# time elapsed :  -0.16626405715942383
# [[93.05994942]
#  [74.33142039]
#  [38.23547902]]
# [[94.94339779]
#  [75.81543752]
#  [37.72749464]]
# [[96.26670275]
#  [76.83921855]
#  [37.72749464]]
# time elapsed :  -0.16663050651550293
# [[97.59000772]
#  [77.86299958]
#  [37.72749464]]
# [[98.91331268]
#  [78.8867806 ]
#  [37.72749464]]
# [[100.19651749]
#  [ 79.87953796]
#  [ 37.68876269]]
# time elapsed :  -0.1683638095855713
# [[101.48039311]
#  [ 80.87142764]
#  [ 37.65003075]]
# [[102.76493896]
#  [ 81.8624492 ]
#  [ 37.6112988 ]]
# [[104.05684827]
#  [ 82.85775923]
#  [ 37.73717763]]
# time elapsed :  -0.1649472713470459
# [[105.34656777]
#  [ 83.85590518]
#  [ 37.86305645]]
# [[106.74082893]
#  [ 84.93986478]
#  [ 37.73717763]]
# time elapsed :  -0.16743731498718262
# [[108.13746818]
#  [ 86.02075858]
#  [ 37.6112988 ]]
# [[109.53647879]
#  [ 87.09858135]
#  [ 37.48541997]]
# [[110.75681509]
#  [ 88.03448504]
#  [ 37.54351789]]
# time elapsed :  -0.16742539405822754
# [[111.97620176]
#  [ 88.97162568]
#  [ 37.60161581]]
# [[113.19463754]
#  [ 89.91000229]
#  [ 37.65971373]]
# [[114.49239482]
#  [ 90.91156632]
#  [ 37.67907971]]
# time elapsed :  -0.15371060371398926
# [[115.78981351]
#  [ 91.91356894]
#  [ 37.69844568]]
# [[117.07352148]
#  [ 92.90567559]
#  [ 37.73717763]]
# time elapsed :  -0.1657421588897705
# [[118.3565585 ]
#  [ 93.89864979]
#  [ 37.77590957]]
# [[119.63892397]
#  [ 94.8924911 ]
#  [ 37.81464152]]
# [[121.00739863]
#  [ 95.95454909]
#  [ 37.94052035]]
# time elapsed :  -0.16753101348876953
# [[122.37353665]
#  [ 97.01961104]
#  [ 38.06639918]]
# [[123.73733144]
#  [ 98.08767183]
#  [ 38.192278  ]]
# [[125.07221163]
#  [ 99.13782767]
#  [ 38.1244971 ]]
# time elapsed :  -0.16700339317321777
# [[126.40833321]
#  [100.18640361]
#  [ 38.05671619]]
# [[127.74569433]
#  [101.23339819]
#  [ 37.98893528]]
# [[129.21082732]
#  [102.37762996]
#  [ 37.96956931]]
# time elapsed :  -0.16526556015014648
# [[130.67634697]
#  [103.52136644]
#  [ 37.95020334]]
# [[131.96234646]
#  [104.52430065]
#  [ 37.95988632]]
# time elapsed :  -0.16470599174499512
# [[133.24817643]
#  [105.52745219]
#  [ 37.96956931]]
# [[134.53383686]
#  [106.53082101]
#  [ 37.9792523 ]]
# [[135.87927286]
#  [107.58120645]
#  [ 38.13418008]]
# time elapsed :  -0.16573166847229004
# [[137.22186371]
#  [108.6352261 ]
#  [ 38.28910787]]
# [[138.56159958]
#  [109.69287226]
#  [ 38.44403566]]
# [[139.8190526 ]
#  [110.69109175]
#  [ 38.50213358]]
# time elapsed :  -0.15289068222045898

# %% [markdown]
# Main to test things :

# %%
thymio_data = []
initial_orientation = 0 #degree
positions = np.array([[0,0],[200,150]])#[0,0],[30,45],[50,50],[17,15],[50,10]
angle_threshold = 3 #degrees
x_est = np.array([[positions[0][0]], [positions[0][1]], [initial_orientation]])
P_est = 0
Ts = 0.1
count = 0
read = 1
angle = 0


async def main():    

    global x_est, P_est, Ts, read, angle
    TURN = 1
    STRAIGHT = 0
    STATE = 0
    await node.wait_for_variables() # wait for Thymio variables values
    rt = RepeatedTimer(Ts, filter)#, x_est, P_est, Ts)
    
    try:
        for i in range(0,20):
            angle = angle_to_rotate([x_est[0][0],x_est[1][0]],positions[1],x_est[2][0]);
            #print("to turn", angle)
            #print("orientation : ",x_est[2][0])
            if (abs(angle)<angle_threshold) and (STATE == TURN):
                print("aaaaaaaa", abs(angle))
                print(STATE)
                read = 0
                #time.sleep(10)
                read = 1
                STATE = STRAIGHT
                print("I wait for straight")
            elif (abs(angle)<angle_threshold) and (STATE == STRAIGHT):
                #straight for Ts=0.1 seconds
                print("straight")
                drive_task = asyncio.create_task(drive_for_seconds(client, Ts))
                await drive_task
    
            else:
                if STATE == STRAIGHT:
                    read = 0
                    #time.sleep(1)
                    read = 1
                    print("I wait for turn")
                    STATE = TURN
                else:
                    if angle>0:
                        right = 1
                    else:
                        right = 0
    
                    turn_task = asyncio.create_task(turn_for_seconds(client, Ts, right))
                    await turn_task
    finally:
        rt.stop()
        node.send_set_variables(motors(0, 0))

await main()
# Out:
# I wait for turn
# [[0]
#  [0]
#  [0]]
# 100 100
# 100 100
# [[7.48000000e+00]
#  [5.67721045e-18]
#  [1.73946630e-16]]
# 100 100
# 100 100
# [[1.49600000e+01]
#  [3.40632627e-17]
#  [3.47893260e-16]]
# 100 100
# 100 100
# [[2.24400000e+01]
#  [8.51581567e-17]
#  [5.21839890e-16]]
# 100 100
# 100 100
# [[2.99200000e+01]
#  [1.58961892e-16]
#  [6.95786520e-16]]
# 100 100
# 100 100
# [[3.7400000e+01]
#  [2.5547447e-16]
#  [8.6973315e-16]]
# 100 100
# 100 100
# [[4.48800000e+01]
#  [3.74695889e-16]
#  [1.04367978e-15]]
# 100 100
# 100 100
# [[5.23600000e+01]
#  [5.16626151e-16]
#  [1.21762641e-15]]
# 100 100
# 100 100
# [[5.98400000e+01]
#  [6.81265254e-16]
#  [1.39157304e-15]]
# 100 100
# 100 100
# [[6.73200000e+01]
#  [8.68613198e-16]
#  [1.56551967e-15]]
# 100 100
# 100 100
# [[7.48000000e+01]
#  [1.07866998e-15]
#  [1.73946630e-15]]
# 100 100
# 100 100
# [[8.22800000e+01]
#  [1.31143561e-15]
#  [1.91341293e-15]]
# 100 100
# 100 100
# [[8.97600000e+01]
#  [1.56691008e-15]
#  [2.08735956e-15]]
# 100 100
# 100 100
# [[9.72400000e+01]
#  [1.84509340e-15]
#  [2.26130619e-15]]
# 100 100
# 100 100
# 100 100
# [[1.04720000e+02]
#  [2.14598555e-15]
#  [2.43525282e-15]]
# 100 100
# [[1.12200000e+02]
#  [2.46958654e-15]
#  [2.60919945e-15]]
# 100 100
# 100 100
# [[1.19680000e+02]
#  [2.81589638e-15]
#  [2.78314608e-15]]
# 100 100
# 100 100
# [[1.27160000e+02]
#  [3.18491506e-15]
#  [2.95709271e-15]]
# 100 100
# 100 100
# [[1.34640000e+02]
#  [3.57664258e-15]
#  [3.13103934e-15]]
# 100 100
# 100 100
# [[1.42120000e+02]
#  [3.99107894e-15]
#  [3.30498597e-15]]
# 100 100

# %%
def motors(left, right):
    return {
        "motor.left.target": [left],
        "motor.right.target": [right],
    }

# %%
import asyncio
import time
    
async def drive_for_seconds(client, seconds):
    # Set the motor speeds
    v = {
        "motor.left.target": [int(99)],
        "motor.right.target": [int(100)],
    }
    await node.set_variables(v)
    await asyncio.sleep(seconds)

    #to delete probably 



async def turn_for_seconds(client, seconds,right):
    # Set the motor speeds
    if seconds != 0:
        if right==1:
            v = {
                "motor.left.target": [int(100)],
                "motor.right.target": [int(-100)],
            }
        else:
            v = {
                "motor.left.target": [int(-100)],
                "motor.right.target": [int(100)],
            }
        await node.set_variables(v)
    await asyncio.sleep(abs(seconds))

# %%
    vstop = {
        "motor.left.target": [int(0)],
        "motor.right.target": [int(0)],
    }
    await node.set_variables(vstop)

# %%
def filter():#x_est, P_est, Ts):
    global x_est, P_est, Ts, read, angle, Vr, Vl
    #thymio_data = []
    #print(x_est)
    #if read = 1:
    thymio_data.append({"left_speed":node["motor.left.speed"],
                        "right_speed":node["motor.right.speed"]}) 

    #print(thymio_data[-1]["left_speed"])
    Vl = thymio_data[-1]["left_speed"]
    Vr = thymio_data[-1]["right_speed"]
    
    '''else:
    if STATE == STRAIGHT:
        Vr = 100
        Vl = 100
    else:
        if angle>0:
            Vr = -100
            Vl = 100
        else:
            Vr = 100
            Vl = -100
'''
    #print(Vr, Vl)

    
    
    x_est, P_est = kalman_filter(x_est, P_est, Vr, Vl, Ts, camera_x=0, camera_y=0, camera_angle=0);
    print(x_est)

# %%
node.send_set_variables(motors(0, 0))
